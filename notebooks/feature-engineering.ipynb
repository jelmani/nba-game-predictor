# %%
import pandas as pd
import numpy as np

# %%
nba_games_df = pd.read_csv("nba_games_processed.csv")
nba_games_df["GAME_DATE"] = pd.to_datetime(nba_games_df["GAME_DATE"])
nba_games_df.head(20)
# Out:
#     SEASON_ID       TEAM_ID TEAM_ABBREVIATION              TEAM_NAME  \
# 0       22019  1.610613e+09               ATL          Atlanta Hawks
# 1       22019  1.610613e+09               WAS     Washington Wizards
# 2       22019  1.610613e+09               LAC            LA Clippers
# 3       22019  1.610613e+09               MIL        Milwaukee Bucks
# 4       22019  1.610613e+09               DEN         Denver Nuggets
# 5       22019  1.610613e+09               IND         Indiana Pacers
# 6       22019  1.610613e+09               LAC            LA Clippers
# 7       22019  1.610613e+09               LAL     Los Angeles Lakers
# 8       22019  1.610613e+09               CHA      Charlotte Hornets
# 9       22019  1.610613e+09               MIL        Milwaukee Bucks
# 10      22019  1.610613e+09               BOS         Boston Celtics
# 11      22019  1.610613e+09               OKC  Oklahoma City Thunder
# 12      22019  1.610613e+09               TOR        Toronto Raptors
# 13      22019  1.610613e+09               DAL       Dallas Mavericks
# 14      22019  1.610613e+09               PHX           Phoenix Suns
# 15      22019  1.610613e+09               PHI     Philadelphia 76ers
# 16      22019  1.610613e+09               SAC       Sacramento Kings
# 17      22019  1.610613e+09               DET        Detroit Pistons
# 18      22019  1.610613e+09               CHI          Chicago Bulls
# 19      22019  1.610613e+09               HOU        Houston Rockets
#
#      GAME_ID  GAME_DATE      MATCHUP WL  MIN  PTS  FGM  FGA  FG_PCT  FG3M  \
# 0   21900431 2019-12-21    ATL @ BKN  L  240  112   39  105   0.371    11
# 1   21900433 2019-12-21    WAS @ PHI  L  239  108   36   88   0.409     7
# 2   21900436 2019-12-21    LAC @ SAS  W  240  134   54   99   0.545    12
# 3   21900434 2019-12-21    MIL @ NYK  W  241  123   41   85   0.482    18
# 4   21900443 2019-12-22    DEN @ LAL  W  241  128   45   92   0.489    11
# 5   21900441 2019-12-22    IND @ MIL  L  240   89   37  100   0.370    12
# 6   21900442 2019-12-22    LAC @ OKC  L  239  112   40   86   0.465    11
# 7   21900443 2019-12-22  LAL vs. DEN  L  240  104   39   83   0.470    10
# 8   21900440 2019-12-22    CHA @ BOS  L  240   93   33   82   0.402    10
# 9   21900441 2019-12-22  MIL vs. IND  W  242  117   44  104   0.423    15
# 10  21900440 2019-12-22  BOS vs. CHA  W  239  119   46   88   0.523    14
# 11  21900442 2019-12-22  OKC vs. LAC  W  241  118   46   97   0.474     9
# 12  21900439 2019-12-22  TOR vs. DAL  W  242  110   37   94   0.394    10
# 13  21900439 2019-12-22    DAL @ TOR  L  240  107   35   90   0.389    15
# 14  21900451 2019-12-23  PHX vs. DEN  L  240  111   42   87   0.483    13
# 15  21900445 2019-12-23    PHI @ DET  W  240  125   52   95   0.547    12
# 16  21900453 2019-12-23  SAC vs. HOU  L  240  104   41   87   0.471     7
# 17  21900445 2019-12-23  DET vs. PHI  L  239  109   43   84   0.512    10
# 18  21900448 2019-12-23    CHI @ ORL  L  239   95   35   88   0.398    13
# 19  21900453 2019-12-23    HOU @ SAC  W  241  113   39   87   0.448    15
#
#     FG3A  FG3_PCT  FTM  FTA  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  PF  \
# 0     48    0.229   23   27   0.852    14    38   52   17    7    5   10  22
# 1     31    0.226   29   34   0.853     7    31   38   18    7    3   11  21
# 2     36    0.333   14   19   0.737    13    30   43   32   11    2   11  19
# 3     43    0.419   23   35   0.657     8    44   52   26    9   14   19  16
# 4     32    0.344   27   30   0.900    17    27   44   31   13    2    8  19
# 5     40    0.300    3    5   0.600    10    38   48   27    7    5   13  15
# 6     27    0.407   21   24   0.875    10    32   42   22    7    2   15  23
# 7     29    0.345   16   22   0.727    18    27   45   18    7    9   19  25
# 8     34    0.294   17   23   0.739     2    25   27   26    3    5    3  17
# 9     44    0.341   14   17   0.824    16    45   61   31   10    9    9   7
# 10    32    0.438   13   16   0.813    10    47   57   25    2    9   11  24
# 11    27    0.333   17   20   0.850    16    33   49   24   10    4   12  20
# 12    34    0.294   26   31   0.839    14    37   51   21   12    5   10  21
# 13    46    0.326   22   27   0.815    14    39   53   27    6    4   17  22
# 14    37    0.351   14   18   0.778     9    29   38   29   10    0   17  19
# 15    30    0.400    9   11   0.818    17    31   48   33    8    8   12  21
# 16    30    0.233   15   23   0.652    11    38   49   20    4    4   17  24
# 17    30    0.333   13   18   0.722     6    24   30   27    9    1   13  14
# 18    37    0.351   12   15   0.800    11    36   47   20    7    5   15  17
# 19    39    0.385   20   23   0.870     6    33   39   18   10    3   11  22
#
#     PLUS_MINUS
# 0        -10.0
# 1        -17.0
# 2         25.0
# 3         21.0
# 4         24.0
# 5        -28.0
# 6         -6.0
# 7        -24.0
# 8        -26.0
# 9         28.0
# 10        26.0
# 11         6.0
# 12         3.0
# 13        -3.0
# 14        -2.0
# 15        16.0
# 16        -9.0
# 17       -16.0
# 18        -8.0
# 19         9.0

# %%
# Function from the NBA docs
def combine_team_games(df, keep_method='home'):
    '''Combine a TEAM_ID-GAME_ID unique table into rows by game. Slow.

        Parameters
        ----------
        df : Input DataFrame.
        keep_method : {'home', 'away', 'winner', 'loser', ``None``}, default 'home'
            - 'home' : Keep rows where TEAM_A is the home team.
            - 'away' : Keep rows where TEAM_A is the away team.
            - 'winner' : Keep rows where TEAM_A is the losing team.
            - 'loser' : Keep rows where TEAM_A is the winning team.
            - ``None`` : Keep all rows. Will result in an output DataFrame the same
                length as the input DataFrame.
                
        Returns
        -------
        result : DataFrame
    '''
    # Join every row to all others with the same game ID.
    joined = pd.merge(df, df, suffixes=['_A', '_B'],
                      on=['SEASON_ID', 'GAME_ID', 'GAME_DATE'])
    # Filter out any row that is joined to itself.
    result = joined[joined.TEAM_ID_A != joined.TEAM_ID_B]
    # Take action based on the keep_method flag.
    if keep_method is None:
        # Return all the rows.
        pass
    elif keep_method.lower() == 'home':
        # Keep rows where TEAM_A is the home team.
        result = result[result.MATCHUP_A.str.contains(' vs. ')]
    elif keep_method.lower() == 'away':
        # Keep rows where TEAM_A is the away team.
        result = result[result.MATCHUP_A.str.contains(' @ ')]
    elif keep_method.lower() == 'winner':
        result = result[result.WL_A == 'W']
    elif keep_method.lower() == 'loser':
        result = result[result.WL_A == 'L']
    else:
        raise ValueError(f'Invalid keep_method: {keep_method}')
    return result

# %%
nba_games_joined = combine_team_games(nba_games_df)

# %%
nba_games_joined.info(), nba_games_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7121 entries, 10 to 28505
# Data columns (total 53 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   SEASON_ID            7121 non-null   int64
#  1   TEAM_ID_A            7121 non-null   float64
#  2   TEAM_ABBREVIATION_A  7121 non-null   object
#  3   TEAM_NAME_A          7121 non-null   object
#  4   GAME_ID              7121 non-null   int64
#  5   GAME_DATE            7121 non-null   datetime64[ns]
#  6   MATCHUP_A            7121 non-null   object
#  7   WL_A                 7121 non-null   object
#  8   MIN_A                7121 non-null   int64
#  9   PTS_A                7121 non-null   int64
#  10  FGM_A                7121 non-null   int64
#  11  FGA_A                7121 non-null   int64
#  12  FG_PCT_A             7121 non-null   float64
#  13  FG3M_A               7121 non-null   int64
#  14  FG3A_A               7121 non-null   int64
#  15  FG3_PCT_A            7121 non-null   float64
#  16  FTM_A                7121 non-null   int64
#  17  FTA_A                7121 non-null   int64
#  18  FT_PCT_A             7121 non-null   float64
#  19  OREB_A               7121 non-null   int64
#  20  DREB_A               7121 non-null   int64
#  21  REB_A                7121 non-null   int64
#  22  AST_A                7121 non-null   int64
#  23  STL_A                7121 non-null   int64
#  24  BLK_A                7121 non-null   int64
#  25  TOV_A                7121 non-null   int64
#  26  PF_A                 7121 non-null   int64
#  27  PLUS_MINUS_A         7121 non-null   float64
#  28  TEAM_ID_B            7121 non-null   float64
#  29  TEAM_ABBREVIATION_B  7121 non-null   object
#  30  TEAM_NAME_B          7121 non-null   object
#  31  MATCHUP_B            7121 non-null   object
#  32  WL_B                 7121 non-null   object
#  33  MIN_B                7121 non-null   int64
#  34  PTS_B                7121 non-null   int64
#  35  FGM_B                7121 non-null   int64
#  36  FGA_B                7121 non-null   int64
#  37  FG_PCT_B             7121 non-null   float64
#  38  FG3M_B               7121 non-null   int64
#  39  FG3A_B               7121 non-null   int64
#  40  FG3_PCT_B            7121 non-null   float64
#  41  FTM_B                7121 non-null   int64
#  42  FTA_B                7121 non-null   int64
#  43  FT_PCT_B             7120 non-null   float64
#  44  OREB_B               7121 non-null   int64
#  45  DREB_B               7121 non-null   int64
#  46  REB_B                7121 non-null   int64
#  47  AST_B                7121 non-null   int64
#  48  STL_B                7121 non-null   int64
#  49  BLK_B                7121 non-null   int64
#  50  TOV_B                7121 non-null   int64
#  51  PF_B                 7121 non-null   int64
#  52  PLUS_MINUS_B         7121 non-null   float64
# dtypes: datetime64[ns](1), float64(10), int64(34), object(8)
# memory usage: 2.9+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14256 entries, 0 to 14255
# Data columns (total 28 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   SEASON_ID          14256 non-null  int64
#  1   TEAM_ID            14256 non-null  float64
#  2   TEAM_ABBREVIATION  14256 non-null  object
#  3   TEAM_NAME          14256 non-null  object
#  4   GAME_ID            14256 non-null  int64
#  5   GAME_DATE          14256 non-null  datetime64[ns]
#  6   MATCHUP            14256 non-null  object
#  7   WL                 14256 non-null  object
#  8   MIN                14256 non-null  int64
#  9   PTS                14256 non-null  int64
#  10  FGM                14256 non-null  int64
#  11  FGA                14256 non-null  int64
#  12  FG_PCT             14256 non-null  float64
#  13  FG3M               14256 non-null  int64
#  14  FG3A               14256 non-null  int64
#  15  FG3_PCT            14256 non-null  float64
#  16  FTM                14256 non-null  int64
#  17  FTA                14256 non-null  int64
#  18  FT_PCT             14255 non-null  float64
#  19  OREB               14256 non-null  int64
#  20  DREB               14256 non-null  int64
#  21  REB                14256 non-null  int64
#  22  AST                14256 non-null  int64
#  23  STL                14256 non-null  int64
#  24  BLK                14256 non-null  int64
#  25  TOV                14256 non-null  int64
#  26  PF                 14256 non-null  int64
#  27  PLUS_MINUS         14256 non-null  float64
# dtypes: datetime64[ns](1), float64(5), int64(18), object(4)
# memory usage: 3.0+ MB
# (None, None)

# %%
nba_games_df[(nba_games_df["TEAM_ABBREVIATION"] == "ATL") & (nba_games_df["GAME_DATE"] < pd.Timestamp('2023-3-08'))].iloc[-5:]
# Out:
#       SEASON_ID       TEAM_ID TEAM_ABBREVIATION      TEAM_NAME   GAME_ID  \
# 8206      22022  1.610613e+09               ATL  Atlanta Hawks  22200911
# 8237      22022  1.610613e+09               ATL  Atlanta Hawks  22200923
# 8270      22022  1.610613e+09               ATL  Atlanta Hawks  22200947
# 8288      22022  1.610613e+09               ATL  Atlanta Hawks  22200958
# 8319      22022  1.610613e+09               ATL  Atlanta Hawks  22200974
#
#       GAME_DATE      MATCHUP WL  MIN  PTS  FGM  FGA  FG_PCT  FG3M  FG3A  \
# 8206 2023-02-26  ATL vs. BKN  W  240  129   45   90   0.500    16    30
# 8237 2023-02-28  ATL vs. WAS  L  239  116   43   93   0.462    13    35
# 8270 2023-03-03  ATL vs. POR  W  239  129   52   91   0.571    12    26
# 8288 2023-03-04    ATL @ MIA  L  239  109   37   79   0.468     9    30
# 8319 2023-03-06    ATL @ MIA  L  239  128   51   92   0.554     9    29
#
#       FG3_PCT  FTM  FTA  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  PF  \
# 8206    0.533   23   28   0.821    13    33   46   20    7    2   15  18
# 8237    0.371   17   19   0.895    13    29   42   21    4    7    9  17
# 8270    0.462   13   16   0.813    10    33   43   30   10    5   17  19
# 8288    0.300   26   30   0.867    10    27   37   22   12    1   16  23
# 8319    0.310   17   23   0.739    12    25   37   28    5    0   10  25
#
#       PLUS_MINUS
# 8206         2.0
# 8237        -3.0
# 8270        18.0
# 8288        -8.0
# 8319        -2.0

# %%
def get_season_to_date_stats(df, date, team_a, team_b):
    '''
    Returns a dataframe of games with the season to date rolling averages for each team
    df - nba games dataframe that is NOT joined per game
    date - string in the format of 2023-02-26
    '''
    out_df = pd.DataFrame()
    
    team_a_prev_games = df[(df["TEAM_ABBREVIATION"] == team_a) & (df["GAME_DATE"] < date)].iloc[-5:]
    team_b_prev_games = df[(df["TEAM_ABBREVIATION"] == team_b) & (df["GAME_DATE"] < date)].iloc[-5:]

    # poss = FGA + 0.44*FTA + TOV - OREB
    out_df["poss_a"] = (team_a_prev_games["FGA"] + (0.44 * team_a_prev_games["FTA"]) + team_a_prev_games["TOV"] - team_a_prev_games["OREB"]).mean()
    out_df["poss_b"] = (team_b_prev_games["FGA"] + (0.44 * team_b_prev_games["FTA"]) + team_b_prev_games["TOV"] - team_b_prev_games["OREB"]).mean()

    return out_df

# %%
get_season_to_date_stats(nba_games_df, "2023-02-26", "NYK", "BKN")
# Out:
# Empty DataFrame
# Columns: [poss_a, poss_b]
# Index: []

# %%
nba_games_joined.head(100)
# Out:
#      SEASON_ID     TEAM_ID_A TEAM_ABBREVIATION_A             TEAM_NAME_A  \
# 10       22019  1.610613e+09                 LAL      Los Angeles Lakers
# 14       22019  1.610613e+09                 MIL         Milwaukee Bucks
# 16       22019  1.610613e+09                 BOS          Boston Celtics
# 18       22019  1.610613e+09                 OKC   Oklahoma City Thunder
# 21       22019  1.610613e+09                 TOR         Toronto Raptors
# 25       22019  1.610613e+09                 PHX            Phoenix Suns
# 29       22019  1.610613e+09                 SAC        Sacramento Kings
# 30       22019  1.610613e+09                 DET         Detroit Pistons
# 43       22019  1.610613e+09                 IND          Indiana Pacers
# 49       22019  1.610613e+09                 MEM       Memphis Grizzlies
# 51       22019  1.610613e+09                 MIA              Miami Heat
# 52       22019  1.610613e+09                 CLE     Cleveland Cavaliers
# 54       22019  1.610613e+09                 ORL           Orlando Magic
# 56       22019  1.610613e+09                 POR  Portland Trail Blazers
# 64       22019  1.610613e+09                 GSW   Golden State Warriors
# 66       22019  1.610613e+09                 NYK         New York Knicks
# 69       22019  1.610613e+09                 LAL      Los Angeles Lakers
# 71       22019  1.610613e+09                 GSW   Golden State Warriors
# 73       22019  1.610613e+09                 PHI      Philadelphia 76ers
# 80       22019  1.610613e+09                 DEN          Denver Nuggets
# 84       22019  1.610613e+09                 TOR         Toronto Raptors
# 93       22019  1.610613e+09                 DAL        Dallas Mavericks
# 97       22019  1.610613e+09                 OKC   Oklahoma City Thunder
# 99       22019  1.610613e+09                 UTA               Utah Jazz
# 100      22019  1.610613e+09                 DET         Detroit Pistons
# 104      22019  1.610613e+09                 SAC        Sacramento Kings
# 108      22019  1.610613e+09                 BKN           Brooklyn Nets
# 113      22019  1.610613e+09                 ATL           Atlanta Hawks
# 120      22019  1.610613e+09                 MIA              Miami Heat
# 122      22019  1.610613e+09                 ORL           Orlando Magic
# 125      22019  1.610613e+09                 GSW   Golden State Warriors
# 126      22019  1.610613e+09                 BOS          Boston Celtics
# 132      22019  1.610613e+09                 CHA       Charlotte Hornets
# 137      22019  1.610613e+09                 POR  Portland Trail Blazers
# 141      22019  1.610613e+09                 BOS          Boston Celtics
# 143      22019  1.610613e+09                 MIL         Milwaukee Bucks
# 145      22019  1.610613e+09                 SAC        Sacramento Kings
# 146      22019  1.610613e+09                 MIN  Minnesota Timberwolves
# 149      22019  1.610613e+09                 HOU         Houston Rockets
# 161      22019  1.610613e+09                 DEN          Denver Nuggets
# 164      22019  1.610613e+09                 NOP    New Orleans Pelicans
# 168      22019  1.610613e+09                 WAS      Washington Wizards
# 171      22019  1.610613e+09                 MIA              Miami Heat
# 178      22019  1.610613e+09                 GSW   Golden State Warriors
# 180      22019  1.610613e+09                 CHI           Chicago Bulls
# 188      22019  1.610613e+09                 SAS       San Antonio Spurs
# 190      22019  1.610613e+09                 LAC             LA Clippers
# 197      22019  1.610613e+09                 TOR         Toronto Raptors
# 200      22019  1.610613e+09                 LAL      Los Angeles Lakers
# 203      22019  1.610613e+09                 DEN          Denver Nuggets
# 206      22019  1.610613e+09                 MEM       Memphis Grizzlies
# 210      22019  1.610613e+09                 NOP    New Orleans Pelicans
# 215      22019  1.610613e+09                 POR  Portland Trail Blazers
# 217      22019  1.610613e+09                 UTA               Utah Jazz
# 221      22019  1.610613e+09                 CHI           Chicago Bulls
# 223      22019  1.610613e+09                 MIN  Minnesota Timberwolves
# 232      22019  1.610613e+09                 WAS      Washington Wizards
# 234      22019  1.610613e+09                 ORL           Orlando Magic
# 240      22019  1.610613e+09                 CHA       Charlotte Hornets
# 243      22019  1.610613e+09                 TOR         Toronto Raptors
# 244      22019  1.610613e+09                 OKC   Oklahoma City Thunder
# 247      22019  1.610613e+09                 HOU         Houston Rockets
# 254      22019  1.610613e+09                 SAS       San Antonio Spurs
# 258      22019  1.610613e+09                 IND          Indiana Pacers
# 261      22019  1.610613e+09                 SAC        Sacramento Kings
# 265      22019  1.610613e+09                 NYK         New York Knicks
# 269      22019  1.610613e+09                 WAS      Washington Wizards
# 271      22019  1.610613e+09                 LAL      Los Angeles Lakers
# 274      22019  1.610613e+09                 MIL         Milwaukee Bucks
# 288      22019  1.610613e+09                 DAL        Dallas Mavericks
# 295      22019  1.610613e+09                 CLE     Cleveland Cavaliers
# 301      22019  1.610613e+09                 SAS       San Antonio Spurs
# 302      22019  1.610613e+09                 MIN  Minnesota Timberwolves
# 304      22019  1.610613e+09                 IND          Indiana Pacers
# 308      22019  1.610613e+09                 CHI           Chicago Bulls
# 310      22019  1.610613e+09                 LAC             LA Clippers
# 312      22019  1.610613e+09                 MIA              Miami Heat
# 314      22019  1.610613e+09                 SAC        Sacramento Kings
# 321      22019  1.610613e+09                 BOS          Boston Celtics
# 323      22019  1.610613e+09                 ORL           Orlando Magic
# 325      22019  1.610613e+09                 HOU         Houston Rockets
# 328      22019  1.610613e+09                 PHX            Phoenix Suns
# 332      22019  1.610613e+09                 LAL      Los Angeles Lakers
# 334      22019  1.610613e+09                 WAS      Washington Wizards
# 341      22019  1.610613e+09                 DAL        Dallas Mavericks
# 343      22019  1.610613e+09                 SAC        Sacramento Kings
# 345      22019  1.610613e+09                 CHI           Chicago Bulls
# 347      22019  1.610613e+09                 LAC             LA Clippers
# 349      22019  1.610613e+09                 CLE     Cleveland Cavaliers
# 355      22019  1.610613e+09                 ATL           Atlanta Hawks
# 359      22019  1.610613e+09                 WAS      Washington Wizards
# 364      22019  1.610613e+09                 MIL         Milwaukee Bucks
# 374      22019  1.610613e+09                 GSW   Golden State Warriors
# 378      22019  1.610613e+09                 ORL           Orlando Magic
# 382      22019  1.610613e+09                 BKN           Brooklyn Nets
# 389      22019  1.610613e+09                 LAL      Los Angeles Lakers
# 395      22019  1.610613e+09                 LAC             LA Clippers
# 398      22019  1.610613e+09                 MIA              Miami Heat
# 400      22019  1.610613e+09                 PHX            Phoenix Suns
# 402      22019  1.610613e+09                 CLE     Cleveland Cavaliers
#
#       GAME_ID  GAME_DATE    MATCHUP_A WL_A  MIN_A  PTS_A  FGM_A  FGA_A  \
# 10   21900443 2019-12-22  LAL vs. DEN    L    240    104     39     83
# 14   21900441 2019-12-22  MIL vs. IND    W    242    117     44    104
# 16   21900440 2019-12-22  BOS vs. CHA    W    239    119     46     88
# 18   21900442 2019-12-22  OKC vs. LAC    W    241    118     46     97
# 21   21900439 2019-12-22  TOR vs. DAL    W    242    110     37     94
# 25   21900451 2019-12-23  PHX vs. DEN    L    240    111     42     87
# 29   21900453 2019-12-23  SAC vs. HOU    L    240    104     41     87
# 30   21900445 2019-12-23  DET vs. PHI    L    239    109     43     84
# 43   21900446 2019-12-23  IND vs. TOR    W    265    120     45     95
# 49   21900450 2019-12-23  MEM vs. SAS    L    241    115     45     96
# 51   21900449 2019-12-23  MIA vs. UTA    W    240    107     37     90
# 52   21900444 2019-12-23  CLE vs. ATL    W    240    121     50     96
# 54   21900448 2019-12-23  ORL vs. CHI    W    239    103     39     81
# 56   21900452 2019-12-23  POR vs. NOP    L    240     94     37     91
# 64   21900454 2019-12-23  GSW vs. MIN    W    239    113     38     87
# 66   21900447 2019-12-23  NYK vs. WAS    L    241    115     44     93
# 69   21900458 2019-12-25  LAL vs. LAC    L    238    106     39     96
# 71   21900457 2019-12-25  GSW vs. HOU    W    239    116     41     87
# 73   21900456 2019-12-25  PHI vs. MIL    W    239    121     44    101
# 80   21900459 2019-12-25  DEN vs. NOP    L    240    100     37     92
# 84   21900455 2019-12-25  TOR vs. BOS    L    240    102     38     80
# 93   21900463 2019-12-26  DAL vs. SAS    W    241    102     38     90
# 97   21900462 2019-12-26  OKC vs. MEM    L    240     97     38     92
# 99   21900465 2019-12-26  UTA vs. POR    W    241    121     46     81
# 100  21900460 2019-12-26  DET vs. WAS    W    242    132     46     86
# 104  21900464 2019-12-26  SAC vs. MIN    L    291    104     37    107
# 108  21900461 2019-12-26  BKN vs. NYK    L    241     82     21     78
# 113  21900469 2019-12-27  ATL vs. MIL    L    239     86     33     91
# 120  21900470 2019-12-27  MIA vs. IND    W    239    113     40     89
# 122  21900468 2019-12-27  ORL vs. PHI    W    240     98     37     88
# 125  21900471 2019-12-27  GSW vs. PHX    W    239    105     38     92
# 126  21900466 2019-12-27  BOS vs. CLE    W    241    129     49     95
# 132  21900467 2019-12-27  CHA vs. OKC    L    265    102     42    101
# 137  21900484 2019-12-28  POR vs. LAL    L    240    120     41     86
# 141  21900473 2019-12-28  BOS vs. TOR    L    240     97     31     78
# 143  21900480 2019-12-28  MIL vs. ORL    W    240    111     43     84
# 145  21900483 2019-12-28  SAC vs. PHX    L    240    110     41     84
# 146  21900479 2019-12-28  MIN vs. CLE    L    242     88     33     93
# 149  21900478 2019-12-28  HOU vs. BKN    W    240    108     44    101
# 161  21900472 2019-12-28  DEN vs. MEM    W    241    119     45     93
# 164  21900474 2019-12-28  NOP vs. IND    W    240    120     43     93
# 168  21900476 2019-12-28  WAS vs. NYK    L    239    100     33     96
# 171  21900475 2019-12-28  MIA vs. PHI    W    266    117     42     94
# 178  21900482 2019-12-28  GSW vs. DAL    L    240    121     45     93
# 180  21900477 2019-12-28  CHI vs. ATL    W    240    116     43     87
# 188  21900481 2019-12-28  SAS vs. DET    W    240    136     53     93
# 190  21900485 2019-12-28  LAC vs. UTA    L    242    107     35     95
# 197  21900486 2019-12-29  TOR vs. OKC    L    241     97     35     83
# 200  21900490 2019-12-29  LAL vs. DAL    W    238    108     38     78
# 203  21900489 2019-12-29  DEN vs. SAC    W    239    120     42     81
# 206  21900487 2019-12-29  MEM vs. CHA    W    238    117     45     93
# 210  21900488 2019-12-29  NOP vs. HOU    W    239    127     50    102
# 215  21900496 2019-12-30  POR vs. PHX    L    240    116     44     96
# 217  21900495 2019-12-30  UTA vs. DET    W    241    104     39     83
# 221  21900493 2019-12-30  CHI vs. MIL    L    240    102     40    107
# 223  21900494 2019-12-30  MIN vs. BKN    W    264    122     42    104
# 232  21900492 2019-12-30  WAS vs. MIA    W    240    123     43     84
# 234  21900491 2019-12-30  ORL vs. ATL    L    241     93     37     89
# 240  21900497 2019-12-31  CHA vs. BOS    L    240     92     34     86
# 243  21900500 2019-12-31  TOR vs. CLE    W    241    117     40     84
# 244  21900503 2019-12-31  OKC vs. DAL    W    240    106     39     91
# 247  21900501 2019-12-31  HOU vs. DEN    W    241    130     46     87
# 254  21900502 2019-12-31  SAS vs. GSW    W    264    117     45     96
# 258  21900498 2019-12-31  IND vs. PHI    W    240    115     42     86
# 261  21900499 2019-12-31  SAC vs. LAC    L    241     87     33     80
# 265  21900505 2020-01-01  NYK vs. POR    W    239    117     47     98
# 269  21900504 2020-01-01  WAS vs. ORL    L    240    101     33     87
# 271  21900507 2020-01-01  LAL vs. PHX    W    239    117     43     90
# 274  21900506 2020-01-01  MIL vs. MIN    W    240    106     40     94
# 288  21900513 2020-01-02  DAL vs. BKN    W    241    123     45     89
# 295  21900508 2020-01-02  CLE vs. CHA    L    239    106     41     81
# 301  21900514 2020-01-02  SAS vs. OKC    L    239    103     40     92
# 302  21900512 2020-01-02  MIN vs. GSW    W    239     99     38     95
# 304  21900509 2020-01-02  IND vs. DEN    L    240    116     43     82
# 308  21900511 2020-01-02  CHI vs. UTA    L    241     98     37     94
# 310  21900516 2020-01-02  LAC vs. DET    W    241    126     50     92
# 312  21900510 2020-01-02  MIA vs. TOR    W    238     84     33     81
# 314  21900515 2020-01-02  SAC vs. MEM    W    240    128     44     90
# 321  21900517 2020-01-03  BOS vs. ATL    W    240    109     41     93
# 323  21900518 2020-01-03  ORL vs. MIA    W    241    105     33     81
# 325  21900520 2020-01-03  HOU vs. PHI    W    240    118     41     86
# 328  21900521 2020-01-03  PHX vs. NYK    W    240    120     42     90
# 332  21900522 2020-01-03  LAL vs. NOP    W    239    123     43     86
# 334  21900519 2020-01-03  WAS vs. POR    L    239    103     38     90
# 341  21900530 2020-01-04  DAL vs. CHA    L    266    120     47    100
# 343  21900533 2020-01-04  SAC vs. NOP    L    241    115     38     85
# 345  21900529 2020-01-04  CHI vs. BOS    L    240    104     34     80
# 347  21900523 2020-01-04  LAC vs. MEM    L    238    114     45    101
# 349  21900527 2020-01-04  CLE vs. OKC    L    240    106     39     85
# 355  21900526 2020-01-04  ATL vs. IND    W    240    116     42     82
# 359  21900528 2020-01-04  WAS vs. DEN    W    241    128     50     91
# 364  21900531 2020-01-04  MIL vs. SAS    W    239    127     43     87
# 374  21900532 2020-01-04  GSW vs. DET    L    240    104     33     82
# 378  21900525 2020-01-04  ORL vs. UTA    L    242     96     38     85
# 382  21900524 2020-01-04  BKN vs. TOR    L    240    102     32     67
# 389  21900538 2020-01-05  LAL vs. DET    W    239    106     42     92
# 395  21900534 2020-01-05  LAC vs. NYK    W    240    135     45     83
# 398  21900535 2020-01-05  MIA vs. POR    W    241    122     47     90
# 400  21900537 2020-01-05  PHX vs. MEM    L    239    114     43     95
# 402  21900536 2020-01-05  CLE vs. MIN    L    239    103     40     84
#
#      FG_PCT_A  FG3M_A  FG3A_A  FG3_PCT_A  FTM_A  FTA_A  FT_PCT_A  OREB_A  \
# 10      0.470      10      29      0.345     16     22     0.727      18
# 14      0.423      15      44      0.341     14     17     0.824      16
# 16      0.523      14      32      0.438     13     16     0.813      10
# 18      0.474       9      27      0.333     17     20     0.850      16
# 21      0.394      10      34      0.294     26     31     0.839      14
# 25      0.483      13      37      0.351     14     18     0.778       9
# 29      0.471       7      30      0.233     15     23     0.652      11
# 30      0.512      10      30      0.333     13     18     0.722       6
# 43      0.474      18      42      0.429     12     20     0.600      13
# 49      0.469      15      37      0.405     10     16     0.625      11
# 51      0.411       9      25      0.360     24     27     0.889      13
# 52      0.521      11      29      0.379     10     12     0.833       7
# 54      0.481      10      26      0.385     15     23     0.652       6
# 56      0.407       4      29      0.138     16     18     0.889       8
# 64      0.437      12      30      0.400     25     30     0.833      13
# 66      0.473      15      36      0.417     12     15     0.800      11
# 69      0.406      12      45      0.267     16     21     0.762      12
# 71      0.471       9      28      0.321     25     28     0.893      11
# 73      0.436      21      44      0.477     12     15     0.800      14
# 80      0.402      12      37      0.324     14     18     0.778      13
# 84      0.475       8      23      0.348     18     22     0.818       7
# 93      0.422      16      40      0.400     10     15     0.667      13
# 97      0.413      10      35      0.286     11     13     0.846       7
# 99      0.568      14      36      0.389     15     22     0.682       7
# 100     0.535      19      48      0.396     21     26     0.808      11
# 104     0.346       9      39      0.231     21     25     0.840      16
# 108     0.269      13      50      0.260     27     36     0.750       9
# 113     0.363      12      41      0.293      8     14     0.571       8
# 120     0.449      16      38      0.421     17     19     0.895      14
# 122     0.420      10      30      0.333     14     23     0.609      10
# 125     0.413       9      27      0.333     20     25     0.800      11
# 126     0.516      14      40      0.350     17     19     0.895      12
# 132     0.416       7      39      0.179     11     18     0.611      17
# 137     0.477      15      35      0.429     23     27     0.852       9
# 141     0.397       7      32      0.219     28     36     0.778       7
# 143     0.512      13      37      0.351     12     18     0.667      14
# 145     0.488      12      31      0.387     16     24     0.667       7
# 146     0.355       8      37      0.216     14     19     0.737      14
# 149     0.436      13      42      0.310      7     16     0.438      16
# 161     0.484       9      29      0.310     20     27     0.741      10
# 164     0.462      18      42      0.429     16     20     0.800      11
# 168     0.344      10      25      0.400     24     31     0.774      14
# 171     0.447      10      28      0.357     23     29     0.793       8
# 178     0.484      18      39      0.462     13     17     0.765       9
# 180     0.494      15      31      0.484     15     19     0.789      13
# 188     0.570      18      35      0.514     12     15     0.800       7
# 190     0.368      12      40      0.300     25     27     0.926      16
# 197     0.422      15      40      0.375     12     12     1.000       8
# 200     0.487       9      23      0.391     23     28     0.821       6
# 203     0.519       8      29      0.276     28     31     0.903      10
# 206     0.484      10      35      0.286     17     17     1.000      14
# 210     0.490      18      44      0.409      9     13     0.692      14
# 215     0.458      14      34      0.412     14     18     0.778      10
# 217     0.470      10      26      0.385     16     20     0.800       9
# 221     0.374      17      44      0.386      5      8     0.625      14
# 223     0.404      17      44      0.386     21     29     0.724      11
# 232     0.512      17      37      0.459     20     30     0.667       9
# 234     0.416       5      25      0.200     14     24     0.583      11
# 240     0.395      12      34      0.353     12     16     0.750       8
# 243     0.476      17      39      0.436     20     25     0.800      10
# 244     0.429       6      27      0.222     22     28     0.786      18
# 247     0.529      16      34      0.471     22     31     0.710      13
# 254     0.469      14      31      0.452     13     17     0.765      10
# 258     0.488      11      25      0.440     20     26     0.769       5
# 261     0.413       8      28      0.286     13     19     0.684      11
# 265     0.480      14      36      0.389      9     14     0.643       9
# 269     0.379       9      31      0.290     26     31     0.839       9
# 271     0.478       7      28      0.250     24     34     0.706      13
# 274     0.426       9      36      0.250     17     26     0.654      12
# 288     0.506      18      38      0.474     15     17     0.882      12
# 295     0.506      13      35      0.371     11     14     0.786       7
# 301     0.435      13      31      0.419     10     12     0.833      14
# 302     0.400      13      43      0.302     10     17     0.588      17
# 304     0.524      12      26      0.462     18     25     0.720       9
# 308     0.394      11      36      0.306     13     17     0.765      15
# 310     0.543      11      28      0.393     15     21     0.714      11
# 312     0.407      12      37      0.324      6     11     0.545       9
# 314     0.489      14      34      0.412     26     31     0.839       7
# 321     0.441       6      25      0.240     21     29     0.724      12
# 323     0.407      13      35      0.371     26     29     0.897       7
# 325     0.477      12      32      0.375     24     32     0.750       8
# 328     0.467      10      28      0.357     26     33     0.788       9
# 332     0.500      14      29      0.483     23     28     0.821       8
# 334     0.422      11      33      0.333     16     25     0.640      14
# 341     0.470      15      50      0.300     11     13     0.846      14
# 343     0.447      12      21      0.571     27     36     0.750      14
# 345     0.425      13      34      0.382     23     31     0.742      11
# 347     0.446       7      30      0.233     17     22     0.773      14
# 349     0.459      14      30      0.467     14     17     0.824       9
# 355     0.512      10      32      0.313     22     24     0.917       4
# 359     0.549       6      16      0.375     22     27     0.815      14
# 364     0.494      17      45      0.378     24     33     0.727       7
# 374     0.402      11      21      0.524     27     32     0.844      11
# 378     0.447      11      37      0.297      9     12     0.750       9
# 382     0.478      13      35      0.371     25     34     0.735       6
# 389     0.457       6      20      0.300     16     23     0.696      11
# 395     0.542      18      32      0.563     27     33     0.818      10
# 398     0.522      18      44      0.409     10     16     0.625      11
# 400     0.453       6      26      0.231     22     26     0.846      12
# 402     0.476       8      25      0.320     15     19     0.789      12
#
#      DREB_A  REB_A  AST_A  STL_A  BLK_A  TOV_A  PF_A  PLUS_MINUS_A  \
# 10       27     45     18      7      9     19    25         -24.0
# 14       45     61     31     10      9      9     7          28.0
# 16       47     57     25      2      9     11    24          26.0
# 18       33     49     24     10      4     12    20           6.0
# 21       37     51     21     12      5     10    21           3.0
# 25       29     38     29     10      0     17    19          -2.0
# 29       38     49     20      4      4     17    24          -9.0
# 30       24     30     27      9      1     13    14         -16.0
# 43       32     45     34      7      8     12    22           5.0
# 49       24     35     28      7      0     13    19         -30.0
# 51       43     56     16      8      3     14    16           3.0
# 52       36     43     19      8      6     23    16           3.0
# 54       40     46     23     10     13     13    15           8.0
# 56       40     48     17      6      6     11    17          -8.0
# 64       42     55     27     11      6     19    27           9.0
# 66       33     44     29      4     10     14    25          -6.0
# 69       30     42     24     11     10     13    23          -5.0
# 71       43     54     27      7      8     16    18          12.0
# 73       35     49     29      9      7      7    12          12.0
# 80       27     40     24     10      4     12    15         -12.0
# 84       27     34     17     13      7     17    13         -16.0
# 93       39     52     22      7      3     14    11           4.0
# 97       27     34     23     11      4      9    14         -13.0
# 99       34     41     22      3      1     10    18           6.0
# 100      37     48     32      5      5     14    23          30.0
# 104      51     67     20      8      8     12    23          -1.0
# 108      41     50     17      3      3     13    19         -12.0
# 113      38     46     20     10      8     18    18         -26.0
# 120      42     56     29      3      2     13    12           1.0
# 122      38     48     26      4      5     15    21           1.0
# 125      30     41     22     10      5     10    17           9.0
# 126      31     43     28      4     10     11    23          12.0
# 132      37     54     26      8      4     15    27          -2.0
# 137      30     39     18      4      8     16    22          -8.0
# 141      24     31     18     11      4     14    17         -16.0
# 143      44     58     30      6      5     23    13          11.0
# 145      29     36     19      3      4     12    16          -2.0
# 146      26     40     17     17      8     18    29          -6.0
# 149      38     54     16      7      6     14    15          10.0
# 161      33     43     28      9      4     10    20           9.0
# 164      38     49     25      9      2     12    18          22.0
# 168      35     49     16     15      3     11    22          -7.0
# 171      35     43     26      6      4      8    21           1.0
# 178      33     42     28      4      3     13    19         -20.0
# 180      38     51     22     13      5     17    15          35.0
# 188      44     51     30      8      7     11    20          27.0
# 190      30     46     22      9      4      7    18         -13.0
# 197      34     42     21      7      2     14    20          -1.0
# 200      33     39     28     12      7     16    23          13.0
# 203      27     37     23      6      4     12    18           5.0
# 206      37     51     30      5      5     14    20          13.0
# 210      32     46     32      9      4      9    17          15.0
# 215      32     42     24      5      4      8    19          -6.0
# 217      37     46     20      7      6     14    21          23.0
# 221      29     43     26     10      2     10    20         -21.0
# 223      49     60     20     12      8     14    22           7.0
# 232      31     40     26     13      6      9    27          18.0
# 234      29     40     22      9      6      9    17          -8.0
# 240      33     41     25      7      4     17    16         -17.0
# 243      35     45     29      5      7     11    15          20.0
# 244      38     56     18      7      5     11    21           5.0
# 247      30     43     20      6      7     15    17          26.0
# 254      43     53     30      6      6     10    18           4.0
# 258      33     38     35      3      6      6    16          18.0
# 261      30     41     20      8      5     15    23         -18.0
# 265      46     55     29      3      6      7    14          24.0
# 269      37     46     18      5      4     13    23         -21.0
# 271      32     45     25      9      5     12    17          10.0
# 274      48     60     24      4     12     17    22           2.0
# 288      34     46     22      4      8     13    21          12.0
# 295      35     42     26      6      3     14    22          -3.0
# 301      31     45     22      1      8      8    22          -6.0
# 302      35     52     22      7      7     12    20          15.0
# 304      25     34     32      7      3      9    21          -8.0
# 308      30     45     22      8      5     10    15          -4.0
# 310      40     51     29      6     11     15    22          14.0
# 312      41     50     23      6      4     13    13           8.0
# 314      34     41     26      9      8     12    24           5.0
# 321      42     54     23      9      7     12    16           3.0
# 323      37     44     25     11      4     10    17          20.0
# 325      38     46     22      6      3     11    24          10.0
# 328      39     48     28      7      3     10    25           8.0
# 332      39     47     29      9      4     12    14          10.0
# 334      27     41     19      5      4     12    28         -19.0
# 341      27     41     28      7      4     10    25          -3.0
# 343      37     51     20      9      3     20    24          -2.0
# 345      26     37     23     15      5     15    22          -7.0
# 347      35     49     20      3      1     13    22         -26.0
# 349      33     42     19      4      0     13    26         -15.0
# 355      36     40     22      8      4     13    28           5.0
# 359      35     49     20      5      6     11    28          14.0
# 364      42     49     23      4     10      9    22           9.0
# 374      31     42     26     13      3     14    19          -7.0
# 378      37     46     21      6      5     10    12         -13.0
# 382      32     38     24      4     11     24    24         -19.0
# 389      39     50     23      8     20     13    22           7.0
# 395      32     42     25      4      3     19    27           3.0
# 398      36     47     34      4      5     10    17          11.0
# 400      34     46     25      7      4     10    19          -7.0
# 402      32     44     15      6      2     20    13         -15.0
#
#         TEAM_ID_B TEAM_ABBREVIATION_B             TEAM_NAME_B  MATCHUP_B WL_B  \
# 10   1.610613e+09                 DEN          Denver Nuggets  DEN @ LAL    W
# 14   1.610613e+09                 IND          Indiana Pacers  IND @ MIL    L
# 16   1.610613e+09                 CHA       Charlotte Hornets  CHA @ BOS    L
# 18   1.610613e+09                 LAC             LA Clippers  LAC @ OKC    L
# 21   1.610613e+09                 DAL        Dallas Mavericks  DAL @ TOR    L
# 25   1.610613e+09                 DEN          Denver Nuggets  DEN @ PHX    W
# 29   1.610613e+09                 HOU         Houston Rockets  HOU @ SAC    W
# 30   1.610613e+09                 PHI      Philadelphia 76ers  PHI @ DET    W
# 43   1.610613e+09                 TOR         Toronto Raptors  TOR @ IND    L
# 49   1.610613e+09                 SAS       San Antonio Spurs  SAS @ MEM    W
# 51   1.610613e+09                 UTA               Utah Jazz  UTA @ MIA    L
# 52   1.610613e+09                 ATL           Atlanta Hawks  ATL @ CLE    L
# 54   1.610613e+09                 CHI           Chicago Bulls  CHI @ ORL    L
# 56   1.610613e+09                 NOP    New Orleans Pelicans  NOP @ POR    W
# 64   1.610613e+09                 MIN  Minnesota Timberwolves  MIN @ GSW    L
# 66   1.610613e+09                 WAS      Washington Wizards  WAS @ NYK    W
# 69   1.610613e+09                 LAC             LA Clippers  LAC @ LAL    W
# 71   1.610613e+09                 HOU         Houston Rockets  HOU @ GSW    L
# 73   1.610613e+09                 MIL         Milwaukee Bucks  MIL @ PHI    L
# 80   1.610613e+09                 NOP    New Orleans Pelicans  NOP @ DEN    W
# 84   1.610613e+09                 BOS          Boston Celtics  BOS @ TOR    W
# 93   1.610613e+09                 SAS       San Antonio Spurs  SAS @ DAL    L
# 97   1.610613e+09                 MEM       Memphis Grizzlies  MEM @ OKC    W
# 99   1.610613e+09                 POR  Portland Trail Blazers  POR @ UTA    L
# 100  1.610613e+09                 WAS      Washington Wizards  WAS @ DET    L
# 104  1.610613e+09                 MIN  Minnesota Timberwolves  MIN @ SAC    W
# 108  1.610613e+09                 NYK         New York Knicks  NYK @ BKN    W
# 113  1.610613e+09                 MIL         Milwaukee Bucks  MIL @ ATL    W
# 120  1.610613e+09                 IND          Indiana Pacers  IND @ MIA    L
# 122  1.610613e+09                 PHI      Philadelphia 76ers  PHI @ ORL    L
# 125  1.610613e+09                 PHX            Phoenix Suns  PHX @ GSW    L
# 126  1.610613e+09                 CLE     Cleveland Cavaliers  CLE @ BOS    L
# 132  1.610613e+09                 OKC   Oklahoma City Thunder  OKC @ CHA    W
# 137  1.610613e+09                 LAL      Los Angeles Lakers  LAL @ POR    W
# 141  1.610613e+09                 TOR         Toronto Raptors  TOR @ BOS    W
# 143  1.610613e+09                 ORL           Orlando Magic  ORL @ MIL    L
# 145  1.610613e+09                 PHX            Phoenix Suns  PHX @ SAC    W
# 146  1.610613e+09                 CLE     Cleveland Cavaliers  CLE @ MIN    W
# 149  1.610613e+09                 BKN           Brooklyn Nets  BKN @ HOU    L
# 161  1.610613e+09                 MEM       Memphis Grizzlies  MEM @ DEN    L
# 164  1.610613e+09                 IND          Indiana Pacers  IND @ NOP    L
# 168  1.610613e+09                 NYK         New York Knicks  NYK @ WAS    W
# 171  1.610613e+09                 PHI      Philadelphia 76ers  PHI @ MIA    L
# 178  1.610613e+09                 DAL        Dallas Mavericks  DAL @ GSW    W
# 180  1.610613e+09                 ATL           Atlanta Hawks  ATL @ CHI    L
# 188  1.610613e+09                 DET         Detroit Pistons  DET @ SAS    L
# 190  1.610613e+09                 UTA               Utah Jazz  UTA @ LAC    W
# 197  1.610613e+09                 OKC   Oklahoma City Thunder  OKC @ TOR    W
# 200  1.610613e+09                 DAL        Dallas Mavericks  DAL @ LAL    L
# 203  1.610613e+09                 SAC        Sacramento Kings  SAC @ DEN    L
# 206  1.610613e+09                 CHA       Charlotte Hornets  CHA @ MEM    L
# 210  1.610613e+09                 HOU         Houston Rockets  HOU @ NOP    L
# 215  1.610613e+09                 PHX            Phoenix Suns  PHX @ POR    W
# 217  1.610613e+09                 DET         Detroit Pistons  DET @ UTA    L
# 221  1.610613e+09                 MIL         Milwaukee Bucks  MIL @ CHI    W
# 223  1.610613e+09                 BKN           Brooklyn Nets  BKN @ MIN    L
# 232  1.610613e+09                 MIA              Miami Heat  MIA @ WAS    L
# 234  1.610613e+09                 ATL           Atlanta Hawks  ATL @ ORL    W
# 240  1.610613e+09                 BOS          Boston Celtics  BOS @ CHA    W
# 243  1.610613e+09                 CLE     Cleveland Cavaliers  CLE @ TOR    L
# 244  1.610613e+09                 DAL        Dallas Mavericks  DAL @ OKC    L
# 247  1.610613e+09                 DEN          Denver Nuggets  DEN @ HOU    L
# 254  1.610613e+09                 GSW   Golden State Warriors  GSW @ SAS    L
# 258  1.610613e+09                 PHI      Philadelphia 76ers  PHI @ IND    L
# 261  1.610613e+09                 LAC             LA Clippers  LAC @ SAC    W
# 265  1.610613e+09                 POR  Portland Trail Blazers  POR @ NYK    L
# 269  1.610613e+09                 ORL           Orlando Magic  ORL @ WAS    W
# 271  1.610613e+09                 PHX            Phoenix Suns  PHX @ LAL    L
# 274  1.610613e+09                 MIN  Minnesota Timberwolves  MIN @ MIL    L
# 288  1.610613e+09                 BKN           Brooklyn Nets  BKN @ DAL    L
# 295  1.610613e+09                 CHA       Charlotte Hornets  CHA @ CLE    W
# 301  1.610613e+09                 OKC   Oklahoma City Thunder  OKC @ SAS    W
# 302  1.610613e+09                 GSW   Golden State Warriors  GSW @ MIN    L
# 304  1.610613e+09                 DEN          Denver Nuggets  DEN @ IND    W
# 308  1.610613e+09                 UTA               Utah Jazz  UTA @ CHI    W
# 310  1.610613e+09                 DET         Detroit Pistons  DET @ LAC    L
# 312  1.610613e+09                 TOR         Toronto Raptors  TOR @ MIA    L
# 314  1.610613e+09                 MEM       Memphis Grizzlies  MEM @ SAC    L
# 321  1.610613e+09                 ATL           Atlanta Hawks  ATL @ BOS    L
# 323  1.610613e+09                 MIA              Miami Heat  MIA @ ORL    L
# 325  1.610613e+09                 PHI      Philadelphia 76ers  PHI @ HOU    L
# 328  1.610613e+09                 NYK         New York Knicks  NYK @ PHX    L
# 332  1.610613e+09                 NOP    New Orleans Pelicans  NOP @ LAL    L
# 334  1.610613e+09                 POR  Portland Trail Blazers  POR @ WAS    W
# 341  1.610613e+09                 CHA       Charlotte Hornets  CHA @ DAL    W
# 343  1.610613e+09                 NOP    New Orleans Pelicans  NOP @ SAC    W
# 345  1.610613e+09                 BOS          Boston Celtics  BOS @ CHI    W
# 347  1.610613e+09                 MEM       Memphis Grizzlies  MEM @ LAC    W
# 349  1.610613e+09                 OKC   Oklahoma City Thunder  OKC @ CLE    W
# 355  1.610613e+09                 IND          Indiana Pacers  IND @ ATL    L
# 359  1.610613e+09                 DEN          Denver Nuggets  DEN @ WAS    L
# 364  1.610613e+09                 SAS       San Antonio Spurs  SAS @ MIL    L
# 374  1.610613e+09                 DET         Detroit Pistons  DET @ GSW    W
# 378  1.610613e+09                 UTA               Utah Jazz  UTA @ ORL    W
# 382  1.610613e+09                 TOR         Toronto Raptors  TOR @ BKN    W
# 389  1.610613e+09                 DET         Detroit Pistons  DET @ LAL    L
# 395  1.610613e+09                 NYK         New York Knicks  NYK @ LAC    L
# 398  1.610613e+09                 POR  Portland Trail Blazers  POR @ MIA    L
# 400  1.610613e+09                 MEM       Memphis Grizzlies  MEM @ PHX    W
# 402  1.610613e+09                 MIN  Minnesota Timberwolves  MIN @ CLE    W
#
#      MIN_B  PTS_B  FGM_B  FGA_B  FG_PCT_B  FG3M_B  FG3A_B  FG3_PCT_B  FTM_B  \
# 10     241    128     45     92     0.489      11      32      0.344     27
# 14     240     89     37    100     0.370      12      40      0.300      3
# 16     240     93     33     82     0.402      10      34      0.294     17
# 18     239    112     40     86     0.465      11      27      0.407     21
# 21     240    107     35     90     0.389      15      46      0.326     22
# 25     239    113     43     78     0.551      15      28      0.536     12
# 29     241    113     39     87     0.448      15      39      0.385     20
# 30     240    125     52     95     0.547      12      30      0.400      9
# 43     266    115     43     94     0.457      11      40      0.275     18
# 49     242    145     60     89     0.674      15      24      0.625     10
# 51     240    104     39     90     0.433      12      36      0.333     14
# 52     239    118     45     95     0.474      15      42      0.357     13
# 54     239     95     35     88     0.398      13      37      0.351     12
# 56     239    102     38     93     0.409      15      35      0.429     11
# 64     240    104     35     87     0.402      11      34      0.324     23
# 66     240    121     47    100     0.470      10      30      0.333     17
# 69     240    111     39     85     0.459       9      25      0.360     24
# 71     240    104     37    100     0.370      16      51      0.314     14
# 73     239    109     45     95     0.474      13      33      0.394      6
# 80     240    112     41     90     0.456      18      43      0.419     12
# 84     239    118     46     92     0.500      14      33      0.424     12
# 93     241     98     40     83     0.482       8      29      0.276     10
# 97     240    110     46     84     0.548      10      25      0.400      8
# 99     240    115     43     89     0.483      15      34      0.441     14
# 100    240    102     38     92     0.413       7      24      0.292     19
# 104    291    105     36    104     0.346      10      46      0.217     23
# 108    239     94     37     92     0.402       9      29      0.310     11
# 113    239    112     46     91     0.505      11      28      0.393      9
# 120    239    112     44     90     0.489      14      31      0.452     10
# 122    240     97     35     87     0.402      10      29      0.345     17
# 125    240     96     35     75     0.467       7      33      0.212     19
# 126    240    117     44     85     0.518       9      23      0.391     20
# 132    265    104     40     89     0.449       5      31      0.161     19
# 137    241    128     47     91     0.516      11      32      0.344     23
# 141    240    113     44     84     0.524      14      34      0.412     11
# 143    240    100     35     87     0.402      14      35      0.400     16
# 145    241    112     45     86     0.523       9      26      0.346     13
# 146    240     94     32     77     0.416       4      20      0.200     26
# 149    240     98     37     92     0.402      11      39      0.282     13
# 161    241    110     41     84     0.488       9      30      0.300     19
# 164    240     98     33     85     0.388       6      28      0.214     26
# 168    240    107     38     85     0.447      11      31      0.355     20
# 171    263    116     42     89     0.472      10      30      0.333     22
# 178    240    141     48     92     0.522      24      51      0.471     21
# 180    239     81     32     86     0.372       9      34      0.265      8
# 188    239    109     40     90     0.444      12      36      0.333     17
# 190    241    120     45     86     0.523      17      35      0.486     13
# 197    241     98     34     78     0.436      10      33      0.303     20
# 200    239     95     32     89     0.360      13      43      0.302     18
# 203    241    115     45     85     0.529      13      34      0.382     12
# 206    239    104     37     86     0.430       9      31      0.290     21
# 210    239    112     42     81     0.519      15      39      0.385     13
# 215    240    122     44     92     0.478      13      23      0.565     21
# 217    239     81     30     79     0.380       4      14      0.286     17
# 221    240    123     46     84     0.548      11      32      0.344     20
# 223    265    115     40     99     0.404      15      41      0.366     20
# 232    241    105     33     73     0.452      10      28      0.357     29
# 234    240    101     39     81     0.481       9      29      0.310     14
# 240    240    109     44     97     0.454      14      38      0.368      7
# 243    240     97     37     87     0.425      10      38      0.263     13
# 244    238    101     33     93     0.355      15      51      0.294     20
# 247    241    104     45     97     0.464       8      25      0.320      6
# 254    266    113     44     96     0.458      12      27      0.444     13
# 258    240     97     37     91     0.407       6      29      0.207     17
# 261    240    105     36     88     0.409      12      36      0.333     21
# 265    239     93     37     94     0.394      10      32      0.313      9
# 269    239    122     45     95     0.474      12      32      0.375     20
# 271    240    107     42     86     0.488       6      23      0.261     17
# 274    240    104     34     91     0.374      15      46      0.326     21
# 288    240    111     42     91     0.462      12      37      0.324     15
# 295    240    109     37     83     0.446      15      38      0.395     20
# 301    240    109     43     89     0.483       9      25      0.360     14
# 302    238     84     33     77     0.429       3      20      0.150     15
# 304    240    124     46     87     0.529       8      27      0.296     24
# 308    240    102     37     76     0.487      11      30      0.367     17
# 310    241    112     40     94     0.426       7      33      0.212     25
# 312    240     76     28     89     0.315       6      42      0.143     14
# 314    241    123     45     93     0.484      13      34      0.382     20
# 321    239    106     39     93     0.419      16      45      0.356     12
# 323    242     85     30     80     0.375       7      37      0.189     18
# 325    241    108     42     92     0.457       6      27      0.222     18
# 328    241    112     41     92     0.446      10      37      0.270     20
# 332    239    113     48    102     0.471      11      37      0.297      6
# 334    242    122     45     88     0.511       6      25      0.240     26
# 341    266    123     42     85     0.494      11      25      0.440     28
# 343    239    117     38     87     0.437      16      45      0.356     25
# 345    240    111     43     82     0.524       8      19      0.421     17
# 347    240    140     49     96     0.510      18      39      0.462     24
# 349    239    121     43     96     0.448      14      37      0.378     21
# 355    239    111     36     87     0.414      10      27      0.370     29
# 359    240    114     40     87     0.460       6      29      0.207     28
# 364    241    118     38     92     0.413      11      32      0.344     31
# 374    239    111     43     83     0.518      11      27      0.407     14
# 378    241    109     42     93     0.452      16      40      0.400      9
# 382    240    121     44     97     0.454      13      32      0.406     20
# 389    241     99     29     78     0.372      11      26      0.423     30
# 395    241    132     48     84     0.571      12      23      0.522     24
# 398    240    111     40     87     0.460      13      37      0.351     18
# 400    241    121     45     83     0.542      18      42      0.429     13
# 402    240    118     47     95     0.495      14      38      0.368     10
#
#      FTA_B  FT_PCT_B  OREB_B  DREB_B  REB_B  AST_B  STL_B  BLK_B  TOV_B  PF_B  \
# 10      30     0.900      17      27     44     31     13      2      8    19
# 14       5     0.600      10      38     48     27      7      5     13    15
# 16      23     0.739       2      25     27     26      3      5      3    17
# 18      24     0.875      10      32     42     22      7      2     15    23
# 21      27     0.815      14      39     53     27      6      4     17    22
# 25      15     0.800       6      33     39     31     10      1     21    24
# 29      23     0.870       6      33     39     18     10      3     11    22
# 30      11     0.818      17      31     48     33      8      8     12    21
# 43      24     0.750      12      38     50     30      6      8     16    22
# 49      14     0.714       4      42     46     36      9      4     12    14
# 51      18     0.778      10      35     45     17     10      6     11    21
# 52      17     0.765       5      32     37     23     11      7     16    20
# 54      15     0.800      11      36     47     20      7      5     15    17
# 56      16     0.688      13      42     55     23      6      6     12    19
# 64      29     0.793       9      31     40     16     10      7     16    18
# 66      30     0.567      16      32     48     27     12      7      8    12
# 69      32     0.750      13      37     50     24      6      6     16    17
# 71      16     0.875      14      35     49     19      8      3     12    25
# 73       8     0.750       8      39     47     23      6      6     10    15
# 80      12     1.000      14      38     52     23      9      5     18    14
# 84      14     0.857      13      32     45     26      7      3     19    22
# 93      15     0.667       5      40     45     18      9      7     13    16
# 97      11     0.727       8      42     50     26      6      8     15    14
# 99      19     0.737      11      32     43     14      4      1     12    21
# 100     27     0.704      18      26     44     18      7      5     12    25
# 104     29     0.793      14      51     65     23      7      5     13    20
# 108     15     0.733      13      47     60     16      6      2     13    27
# 113     13     0.692       6      50     56     29      9      8     18    13
# 120     12     0.833       2      32     34     27      8      4      4    16
# 122     21     0.810       7      38     45     23     10      3     15    22
# 125     24     0.792      11      38     49     22      6      1     26    21
# 126     29     0.690       6      32     38     22      7      3     11    17
# 132     31     0.613      10      39     49     19      8      4     14    23
# 137     28     0.821      11      33     44     32      6      7      9    25
# 141     17     0.647      15      38     53     27      8      3     22    32
# 143     19     0.842       5      29     34     21     16      7     11    17
# 145     15     0.867       7      33     40     30     10      2     13    21
# 146     36     0.722      14      46     60     13      9      4     28    21
# 149     21     0.619       9      38     47     24      7      5     15    15
# 161     25     0.760      11      34     45     32      5      5     17    24
# 164     29     0.897      12      34     46     17      6      2     18    16
# 168     26     0.769      11      45     56     25      5      5     21    25
# 171     29     0.759       8      39     47     24      5      4      9    24
# 178     21     1.000       9      37     46     35     11      7     13    17
# 180     11     0.727       9      30     39     24      8      5     19    16
# 188     30     0.567      10      30     40     20      9      5     11    15
# 190     17     0.765       6      41     47     25      4      2     12    20
# 197     23     0.870       8      35     43     15      8      6     17    14
# 200     20     0.900      13      32     45     17     11      4     18    23
# 203     17     0.706       9      26     35     32      5      4     12    26
# 206     32     0.656      11      31     42     23      8      4     14    19
# 210     20     0.650       8      33     41     29      5      3     17    16
# 215     22     0.955      10      34     44     29      6      4      9    17
# 217     23     0.739      10      33     43     14     10      5     17    20
# 221     24     0.833      10      49     59     29      6      9     16    17
# 223     27     0.741       7      51     58     22      4      6     16    25
# 232     39     0.744      10      34     44     18      5      1     18    22
# 234     17     0.824      11      41     52     21      8      4     20    20
# 240     10     0.700      15      39     54     25     12      9     10    16
# 243     16     0.813       8      33     41     21      5      4     14    19
# 244     27     0.741      17      32     49     19      5      4     10    24
# 247      9     0.667      14      25     39     25      7      5     16    22
# 254     18     0.722       9      35     44     31      5      6      8    14
# 258     20     0.850      14      33     47     24      4      6     12    22
# 261     22     0.955      14      37     51     21      9      2     11    17
# 265     15     0.600      10      37     47     17      4      5      8    11
# 269     27     0.741      11      41     52     25     11      6      9    21
# 271     23     0.739      11      36     47     32      7      3     14    28
# 274     28     0.750       6      42     48     18      7      8     11    25
# 288     17     0.882      12      32     44     29      5      1     11    21
# 295     24     0.833      10      29     39     25      5      0     11    15
# 301     20     0.700       8      35     43     19      7      6      4    14
# 302     21     0.714       7      36     43     20      9      1     16    20
# 304     27     0.889      15      32     47     27      7      2     10    21
# 308     22     0.773       7      35     42     24      5      6     17    17
# 310     35     0.714      12      33     45     20     10      1     11    23
# 312     17     0.824      13      35     48     20      4      6     10    12
# 314     21     0.952       8      34     42     31      4      0     17    25
# 321     15     0.800       6      36     42     26      6      5     14    24
# 323     23     0.783      10      39     49     16      7      2     18    20
# 325     25     0.720      10      34     44     32      7      6     11    22
# 328     30     0.667      13      39     52     19      7      7     15    26
# 332      7     0.857       9      31     40     24      4     10     11    20
# 334     33     0.788      11      30     41     16      6      7      7    21
# 341     31     0.903      16      37     53     27      5      5     17    22
# 343     33     0.758       9      35     44     28     11      3     15    25
# 345     21     0.810      13      31     44     22     10      5     19    22
# 347     28     0.857      11      43     54     36      8     10      9    23
# 349     26     0.808      18      34     52     24      6      4     11    16
# 355     35     0.829      13      26     39     24      8      4     11    24
# 359     34     0.824       9      24     33     18      6      2     12    23
# 364     34     0.912      11      39     50     20      7      0      8    20
# 374     16     0.875       9      37     46     24     13      5     21    25
# 378     14     0.643      14      37     51     22      3      3      8    10
# 382     28     0.714      15      28     43     21     10      4      7    25
# 389     35     0.857       6      37     43     21      8      6     16    22
# 395     37     0.649       8      29     37     22     11      4     16    26
# 398     20     0.900       8      32     40     21      5      4     10    15
# 400     17     0.765       3      39     42     31      4      8     16    22
# 402     13     0.769      14      29     43     32     16      8     16    19
#
#      PLUS_MINUS_B
# 10           24.0
# 14          -28.0
# 16          -26.0
# 18           -6.0
# 21           -3.0
# 25            2.0
# 29            9.0
# 30           16.0
# 43           -5.0
# 49           30.0
# 51           -3.0
# 52           -3.0
# 54           -8.0
# 56            8.0
# 64           -9.0
# 66            6.0
# 69            5.0
# 71          -12.0
# 73          -12.0
# 80           12.0
# 84           16.0
# 93           -4.0
# 97           13.0
# 99           -6.0
# 100         -30.0
# 104           1.0
# 108          12.0
# 113          26.0
# 120          -1.0
# 122          -1.0
# 125          -9.0
# 126         -12.0
# 132           2.0
# 137           8.0
# 141          16.0
# 143         -11.0
# 145           2.0
# 146           6.0
# 149         -10.0
# 161          -9.0
# 164         -22.0
# 168           7.0
# 171          -1.0
# 178          20.0
# 180         -35.0
# 188         -27.0
# 190          13.0
# 197           1.0
# 200         -13.0
# 203          -5.0
# 206         -13.0
# 210         -15.0
# 215           6.0
# 217         -23.0
# 221          21.0
# 223          -7.0
# 232         -18.0
# 234           8.0
# 240          17.0
# 243         -20.0
# 244          -5.0
# 247         -26.0
# 254          -4.0
# 258         -18.0
# 261          18.0
# 265         -24.0
# 269          21.0
# 271         -10.0
# 274          -2.0
# 288         -12.0
# 295           3.0
# 301           6.0
# 302         -15.0
# 304           8.0
# 308           4.0
# 310         -14.0
# 312          -8.0
# 314          -5.0
# 321          -3.0
# 323         -20.0
# 325         -10.0
# 328          -8.0
# 332         -10.0
# 334          19.0
# 341           3.0
# 343           2.0
# 345           7.0
# 347          26.0
# 349          15.0
# 355          -5.0
# 359         -14.0
# 364          -9.0
# 374           7.0
# 378          13.0
# 382          19.0
# 389          -7.0
# 395          -3.0
# 398         -11.0
# 400           7.0
# 402          15.0

# %%
def append_calculated_stats_to_joined_df(df):
    df['poss_A'] = df['FGA_A'] + 0.44*df['FTA_A'] + df['TOV_A'] - df['OREB_A']
    df['poss_B'] = df['FGA_B'] + 0.44*df['FTA_B'] + df['TOV_B'] - df['OREB_B']
    
    df['ortg_A'] = 100 * df['PTS_A'] / df['poss_A']
    df['ortg_B'] = 100 * df['PTS_B'] / df['poss_B']
    
    df['drtg_A'] = 100 * df['PTS_B'] / df['poss_B']
    df['drtg_B'] = 100 * df['PTS_A'] / df['poss_A']
    
    df['eFG_A']  = (df['FGM_A'] + 0.5*df['FG3M_A']) / df['FGA_A']
    df['eFG_B']  = (df['FGM_B'] + 0.5*df['FG3M_B']) / df['FGA_B']
    
    df['tovr_A'] = df['TOV_A'] / df['poss_A']
    df['tovr_B'] = df['TOV_B'] / df['poss_B']
    
    
    df['orb%_A'] = df['OREB_A'] / (df['OREB_A'] + df['DREB_B'])
    df['orb%_B'] = df['OREB_B'] / (df['OREB_B'] + df['DREB_A'])
    
    df['ftr_A']  = df['FTA_A'] / df['FGA_A']
    df['ftr_B']  = df['FTA_B'] / df['FGA_B']
    
    df['pace_A'] = 48 * (df['poss_A'] / (df['MIN_A']/5))
    df['pace_B'] = 48 * (df['poss_B'] / (df['MIN_B']/5))

# %%
# append_calculated_stats_to_joined_df(nba_games_joined)
# nba_games_joined.head()
nba_games_joined.head().to_csv("sample_joined_w_stats.csv", index=False)

# %%
nba_games_joined.shift(1).rolling(window=5).

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
nba_games_joined.head(80)

# %% [markdown]
# you want a dataframe that each row is a game and each column is a feature. most of which are rolling averages from the previous games.
# we will take the joined df and add the relevant stats for each game for each team. then we can compute the rolling averages by going through each game and

# %%
# nba_games_joined.rename(columns={'orb%__B':'orb%_B'}, inplace=True)
# nba_games_joined[nba_games_joined["TEAM_ID_A"] == 1610612749.0]

# %%
nba_games_joined[nba_games_joined["GAME_ID"] == 21900447]
# nba_games_joined.head(40)
# Out:
#     SEASON_ID     TEAM_ID_A TEAM_ABBREVIATION_A      TEAM_NAME_A   GAME_ID  \
# 66      22019  1.610613e+09                 NYK  New York Knicks  21900447
#
#     GAME_DATE    MATCHUP_A WL_A  MIN_A  PTS_A  FGM_A  FGA_A  FG_PCT_A  FG3M_A  \
# 66 2019-12-23  NYK vs. WAS    L    241    115     44     93     0.473      15
#
#     FG3A_A  FG3_PCT_A  FTM_A  FTA_A  FT_PCT_A  OREB_A  DREB_A  REB_A  AST_A  \
# 66      36      0.417     12     15       0.8      11      33     44     29
#
#     STL_A  BLK_A  TOV_A  PF_A  PLUS_MINUS_A     TEAM_ID_B TEAM_ABBREVIATION_B  \
# 66      4     10     14    25          -6.0  1.610613e+09                 WAS
#
#            TEAM_NAME_B  MATCHUP_B WL_B  MIN_B  PTS_B  FGM_B  FGA_B  FG_PCT_B  \
# 66  Washington Wizards  WAS @ NYK    W    240    121     47    100      0.47
#
#     FG3M_B  FG3A_B  FG3_PCT_B  FTM_B  FTA_B  FT_PCT_B  OREB_B  DREB_B  REB_B  \
# 66      10      30      0.333     17     30     0.567      16      32     48
#
#     AST_B  STL_B  BLK_B  TOV_B  PF_B  PLUS_MINUS_B  poss_A  poss_B     ortg_A  \
# 66     27     12      7      8    12           6.0   102.6   105.2  112.08577
#
#         ortg_B      drtg_A     drtg_B     eFG_A  eFG_B    tovr_A    tovr_B  \
# 66  115.019011  115.019011  112.08577  0.553763   0.52  0.136452  0.076046
#
#       orb%_A    orb%_B    ftr_A  ftr_B      pace_A  pace_B
# 66  0.255814  0.326531  0.16129    0.3  102.174274   105.2

# %%
nba_games_df[nba_games_df["GAME_ID"] == 21900447]
# Out:
#     SEASON_ID       TEAM_ID TEAM_ABBREVIATION           TEAM_NAME   GAME_ID  \
# 20      22019  1.610613e+09               WAS  Washington Wizards  21900447
# 35      22019  1.610613e+09               NYK     New York Knicks  21900447
#
#     GAME_DATE      MATCHUP WL  MIN  PTS  FGM  FGA  FG_PCT  FG3M  FG3A  \
# 20 2019-12-23    WAS @ NYK  W  240  121   47  100   0.470    10    30
# 35 2019-12-23  NYK vs. WAS  L  241  115   44   93   0.473    15    36
#
#     FG3_PCT  FTM  FTA  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  PF  \
# 20    0.333   17   30   0.567    16    32   48   27   12    7    8  12
# 35    0.417   12   15   0.800    11    33   44   29    4   10   14  25
#
#     PLUS_MINUS
# 20         6.0
# 35        -6.0

# %%
stats = ['poss','ortg','drtg','eFG','tovr','orb%','ftr','pace']
a_subset = ["GAME_ID", "TEAM_ABBREVIATION_A"] + [f'{s}_A' for s in stats]
nba_joined_subset_a = nba_games_joined[a_subset]
games_by_home_w_stats = nba_games_df.merge(nba_joined_subset_a, left_on=["GAME_ID", "TEAM_ABBREVIATION"], right_on=["GAME_ID", "TEAM_ABBREVIATION_A"])

# %%
b_subset = ["GAME_ID", "TEAM_ABBREVIATION_B"] + [f'{s}_B' for s in stats]
nba_joined_subset_b = nba_games_joined[b_subset]
games_by_away_w_stats = nba_games_df.merge(nba_joined_subset_b, left_on=["GAME_ID", "TEAM_ABBREVIATION"], right_on=["GAME_ID", "TEAM_ABBREVIATION_B"])

# %%
nba_games_df[nba_games_df["GAME_ID"] == 21900443]
# Out:
#    SEASON_ID       TEAM_ID TEAM_ABBREVIATION           TEAM_NAME   GAME_ID  \
# 4      22019  1.610613e+09               DEN      Denver Nuggets  21900443
# 7      22019  1.610613e+09               LAL  Los Angeles Lakers  21900443
#
#    GAME_DATE      MATCHUP WL  MIN  PTS  FGM  FGA  FG_PCT  FG3M  FG3A  FG3_PCT  \
# 4 2019-12-22    DEN @ LAL  W  241  128   45   92   0.489    11    32    0.344
# 7 2019-12-22  LAL vs. DEN  L  240  104   39   83   0.470    10    29    0.345
#
#    FTM  FTA  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  PF  PLUS_MINUS
# 4   27   30   0.900    17    27   44   31   13    2    8  19        24.0
# 7   16   22   0.727    18    27   45   18    7    9   19  25       -24.0

# %%
nba_games_joined[nba_games_joined["GAME_ID"] == 21900443]
# Out:
#     SEASON_ID     TEAM_ID_A TEAM_ABBREVIATION_A         TEAM_NAME_A   GAME_ID  \
# 10      22019  1.610613e+09                 LAL  Los Angeles Lakers  21900443
#
#     GAME_DATE    MATCHUP_A WL_A  MIN_A  PTS_A  FGM_A  FGA_A  FG_PCT_A  FG3M_A  \
# 10 2019-12-22  LAL vs. DEN    L    240    104     39     83      0.47      10
#
#     FG3A_A  FG3_PCT_A  FTM_A  FTA_A  FT_PCT_A  OREB_A  DREB_A  REB_A  AST_A  \
# 10      29      0.345     16     22     0.727      18      27     45     18
#
#     STL_A  BLK_A  TOV_A  PF_A  PLUS_MINUS_A     TEAM_ID_B TEAM_ABBREVIATION_B  \
# 10      7      9     19    25         -24.0  1.610613e+09                 DEN
#
#        TEAM_NAME_B  MATCHUP_B WL_B  MIN_B  PTS_B  FGM_B  FGA_B  FG_PCT_B  \
# 10  Denver Nuggets  DEN @ LAL    W    241    128     45     92     0.489
#
#     FG3M_B  FG3A_B  FG3_PCT_B  FTM_B  FTA_B  FT_PCT_B  OREB_B  DREB_B  REB_B  \
# 10      11      32      0.344     27     30       0.9      17      27     44
#
#     AST_B  STL_B  BLK_B  TOV_B  PF_B  PLUS_MINUS_B  poss_A  poss_B  \
# 10     31     13      2      8    19          24.0   93.68    96.2
#
#         ortg_A      ortg_B      drtg_A      drtg_B    eFG_A     eFG_B  \
# 10  111.016225  133.056133  133.056133  111.016225  0.53012  0.548913
#
#       tovr_A   tovr_B  orb%_A    orb%_B    ftr_A     ftr_B  pace_A    pace_B
# 10  0.202818  0.08316     0.4  0.386364  0.26506  0.326087   93.68  95.80083

# %%
games_by_home_w_stats.head(10)
# Out:
#    SEASON_ID       TEAM_ID TEAM_ABBREVIATION              TEAM_NAME   GAME_ID  \
# 0      22019  1.610613e+09               LAL     Los Angeles Lakers  21900443
# 1      22019  1.610613e+09               MIL        Milwaukee Bucks  21900441
# 2      22019  1.610613e+09               BOS         Boston Celtics  21900440
# 3      22019  1.610613e+09               OKC  Oklahoma City Thunder  21900442
# 4      22019  1.610613e+09               TOR        Toronto Raptors  21900439
# 5      22019  1.610613e+09               PHX           Phoenix Suns  21900451
# 6      22019  1.610613e+09               SAC       Sacramento Kings  21900453
# 7      22019  1.610613e+09               DET        Detroit Pistons  21900445
# 8      22019  1.610613e+09               IND         Indiana Pacers  21900446
# 9      22019  1.610613e+09               MEM      Memphis Grizzlies  21900450
#
#    GAME_DATE      MATCHUP WL  MIN  PTS  FGM  FGA  FG_PCT  FG3M  FG3A  FG3_PCT  \
# 0 2019-12-22  LAL vs. DEN  L  240  104   39   83   0.470    10    29    0.345
# 1 2019-12-22  MIL vs. IND  W  242  117   44  104   0.423    15    44    0.341
# 2 2019-12-22  BOS vs. CHA  W  239  119   46   88   0.523    14    32    0.438
# 3 2019-12-22  OKC vs. LAC  W  241  118   46   97   0.474     9    27    0.333
# 4 2019-12-22  TOR vs. DAL  W  242  110   37   94   0.394    10    34    0.294
# 5 2019-12-23  PHX vs. DEN  L  240  111   42   87   0.483    13    37    0.351
# 6 2019-12-23  SAC vs. HOU  L  240  104   41   87   0.471     7    30    0.233
# 7 2019-12-23  DET vs. PHI  L  239  109   43   84   0.512    10    30    0.333
# 8 2019-12-23  IND vs. TOR  W  265  120   45   95   0.474    18    42    0.429
# 9 2019-12-23  MEM vs. SAS  L  241  115   45   96   0.469    15    37    0.405
#
#    FTM  FTA  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  PF  PLUS_MINUS  \
# 0   16   22   0.727    18    27   45   18    7    9   19  25       -24.0
# 1   14   17   0.824    16    45   61   31   10    9    9   7        28.0
# 2   13   16   0.813    10    47   57   25    2    9   11  24        26.0
# 3   17   20   0.850    16    33   49   24   10    4   12  20         6.0
# 4   26   31   0.839    14    37   51   21   12    5   10  21         3.0
# 5   14   18   0.778     9    29   38   29   10    0   17  19        -2.0
# 6   15   23   0.652    11    38   49   20    4    4   17  24        -9.0
# 7   13   18   0.722     6    24   30   27    9    1   13  14       -16.0
# 8   12   20   0.600    13    32   45   34    7    8   12  22         5.0
# 9   10   16   0.625    11    24   35   28    7    0   13  19       -30.0
#
#   TEAM_ABBREVIATION_A  poss_A      ortg_A      drtg_A     eFG_A    tovr_A  \
# 0                 LAL   93.68  111.016225  133.056133  0.530120  0.202818
# 1                 MIL  104.48  111.983155   84.600760  0.495192  0.086141
# 2                 BOS   96.04  123.906706   99.871134  0.602273  0.114536
# 3                 OKC  101.80  115.913556  110.279638  0.520619  0.117878
# 4                 TOR  103.64  106.136627  102.021358  0.446809  0.096488
# 5                 PHX  102.92  107.850758  113.453815  0.557471  0.165177
# 6                 SAC  103.12  100.853375  110.654132  0.511494  0.164856
# 7                 DET   98.92  110.190053  131.800928  0.571429  0.131419
# 8                 IND  102.80  116.731518  105.932203  0.568421  0.116732
# 9                 MEM  105.04  109.482102  140.558356  0.546875  0.123762
#
#      orb%_A     ftr_A      pace_A
# 0  0.400000  0.265060   93.680000
# 1  0.296296  0.163462  103.616529
# 2  0.285714  0.181818   96.441841
# 3  0.333333  0.206186  101.377593
# 4  0.264151  0.329787  102.783471
# 5  0.214286  0.206897  102.920000
# 6  0.250000  0.264368  103.120000
# 7  0.162162  0.214286   99.333891
# 8  0.254902  0.210526   93.101887
# 9  0.207547  0.166667  104.604149

# %%
games_by_away_w_stats.head(10)
# Out:
#    SEASON_ID       TEAM_ID TEAM_ABBREVIATION           TEAM_NAME   GAME_ID  \
# 0      22019  1.610613e+09               DEN      Denver Nuggets  21900443
# 1      22019  1.610613e+09               IND      Indiana Pacers  21900441
# 2      22019  1.610613e+09               LAC         LA Clippers  21900442
# 3      22019  1.610613e+09               CHA   Charlotte Hornets  21900440
# 4      22019  1.610613e+09               DAL    Dallas Mavericks  21900439
# 5      22019  1.610613e+09               PHI  Philadelphia 76ers  21900445
# 6      22019  1.610613e+09               CHI       Chicago Bulls  21900448
# 7      22019  1.610613e+09               HOU     Houston Rockets  21900453
# 8      22019  1.610613e+09               WAS  Washington Wizards  21900447
# 9      22019  1.610613e+09               ATL       Atlanta Hawks  21900444
#
#    GAME_DATE    MATCHUP WL  MIN  PTS  FGM  FGA  FG_PCT  FG3M  FG3A  FG3_PCT  \
# 0 2019-12-22  DEN @ LAL  W  241  128   45   92   0.489    11    32    0.344
# 1 2019-12-22  IND @ MIL  L  240   89   37  100   0.370    12    40    0.300
# 2 2019-12-22  LAC @ OKC  L  239  112   40   86   0.465    11    27    0.407
# 3 2019-12-22  CHA @ BOS  L  240   93   33   82   0.402    10    34    0.294
# 4 2019-12-22  DAL @ TOR  L  240  107   35   90   0.389    15    46    0.326
# 5 2019-12-23  PHI @ DET  W  240  125   52   95   0.547    12    30    0.400
# 6 2019-12-23  CHI @ ORL  L  239   95   35   88   0.398    13    37    0.351
# 7 2019-12-23  HOU @ SAC  W  241  113   39   87   0.448    15    39    0.385
# 8 2019-12-23  WAS @ NYK  W  240  121   47  100   0.470    10    30    0.333
# 9 2019-12-23  ATL @ CLE  L  239  118   45   95   0.474    15    42    0.357
#
#    FTM  FTA  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  PF  PLUS_MINUS  \
# 0   27   30   0.900    17    27   44   31   13    2    8  19        24.0
# 1    3    5   0.600    10    38   48   27    7    5   13  15       -28.0
# 2   21   24   0.875    10    32   42   22    7    2   15  23        -6.0
# 3   17   23   0.739     2    25   27   26    3    5    3  17       -26.0
# 4   22   27   0.815    14    39   53   27    6    4   17  22        -3.0
# 5    9   11   0.818    17    31   48   33    8    8   12  21        16.0
# 6   12   15   0.800    11    36   47   20    7    5   15  17        -8.0
# 7   20   23   0.870     6    33   39   18   10    3   11  22         9.0
# 8   17   30   0.567    16    32   48   27   12    7    8  12         6.0
# 9   13   17   0.765     5    32   37   23   11    7   16  20        -3.0
#
#   TEAM_ABBREVIATION_B  poss_B      ortg_B      drtg_B     eFG_B    tovr_B  \
# 0                 DEN   96.20  133.056133  111.016225  0.548913  0.083160
# 1                 IND  105.20   84.600760  111.983155  0.430000  0.123574
# 2                 LAC  101.56  110.279638  115.913556  0.529070  0.147696
# 3                 CHA   93.12   99.871134  123.906706  0.463415  0.032216
# 4                 DAL  104.88  102.021358  106.136627  0.472222  0.162090
# 5                 PHI   94.84  131.800928  110.190053  0.610526  0.126529
# 6                 CHI   98.60   96.348884  104.973502  0.471591  0.152130
# 7                 HOU  102.12  110.654132  100.853375  0.534483  0.107716
# 8                 WAS  105.20  115.019011  112.085770  0.520000  0.076046
# 9                 ATL  113.48  103.983081  103.171896  0.552632  0.140994
#
#      orb%_B     ftr_B      pace_B
# 0  0.386364  0.326087   95.800830
# 1  0.181818  0.050000  105.200000
# 2  0.232558  0.279070  101.984937
# 3  0.040816  0.280488   93.120000
# 4  0.274510  0.300000  104.880000
# 5  0.414634  0.115789   94.840000
# 6  0.215686  0.170455   99.012552
# 7  0.136364  0.264368  101.696266
# 8  0.326531  0.300000  105.200000
# 9  0.121951  0.178947  113.954812

# %%
games_by_home_w_stats.merge(games_by_away_w_stats[b_subset], on="GAME_ID").head()
# Out:
#    SEASON_ID       TEAM_ID TEAM_ABBREVIATION              TEAM_NAME   GAME_ID  \
# 0      22019  1.610613e+09               LAL     Los Angeles Lakers  21900443
# 1      22019  1.610613e+09               MIL        Milwaukee Bucks  21900441
# 2      22019  1.610613e+09               BOS         Boston Celtics  21900440
# 3      22019  1.610613e+09               OKC  Oklahoma City Thunder  21900442
# 4      22019  1.610613e+09               TOR        Toronto Raptors  21900439
#
#    GAME_DATE      MATCHUP WL  MIN  PTS  FGM  FGA  FG_PCT  FG3M  FG3A  FG3_PCT  \
# 0 2019-12-22  LAL vs. DEN  L  240  104   39   83   0.470    10    29    0.345
# 1 2019-12-22  MIL vs. IND  W  242  117   44  104   0.423    15    44    0.341
# 2 2019-12-22  BOS vs. CHA  W  239  119   46   88   0.523    14    32    0.438
# 3 2019-12-22  OKC vs. LAC  W  241  118   46   97   0.474     9    27    0.333
# 4 2019-12-22  TOR vs. DAL  W  242  110   37   94   0.394    10    34    0.294
#
#    FTM  FTA  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  PF  PLUS_MINUS  \
# 0   16   22   0.727    18    27   45   18    7    9   19  25       -24.0
# 1   14   17   0.824    16    45   61   31   10    9    9   7        28.0
# 2   13   16   0.813    10    47   57   25    2    9   11  24        26.0
# 3   17   20   0.850    16    33   49   24   10    4   12  20         6.0
# 4   26   31   0.839    14    37   51   21   12    5   10  21         3.0
#
#   TEAM_ABBREVIATION_A  poss_A      ortg_A      drtg_A     eFG_A    tovr_A  \
# 0                 LAL   93.68  111.016225  133.056133  0.530120  0.202818
# 1                 MIL  104.48  111.983155   84.600760  0.495192  0.086141
# 2                 BOS   96.04  123.906706   99.871134  0.602273  0.114536
# 3                 OKC  101.80  115.913556  110.279638  0.520619  0.117878
# 4                 TOR  103.64  106.136627  102.021358  0.446809  0.096488
#
#      orb%_A     ftr_A      pace_A TEAM_ABBREVIATION_B  poss_B      ortg_B  \
# 0  0.400000  0.265060   93.680000                 DEN   96.20  133.056133
# 1  0.296296  0.163462  103.616529                 IND  105.20   84.600760
# 2  0.285714  0.181818   96.441841                 CHA   93.12   99.871134
# 3  0.333333  0.206186  101.377593                 LAC  101.56  110.279638
# 4  0.264151  0.329787  102.783471                 DAL  104.88  102.021358
#
#        drtg_B     eFG_B    tovr_B    orb%_B     ftr_B      pace_B
# 0  111.016225  0.548913  0.083160  0.386364  0.326087   95.800830
# 1  111.983155  0.430000  0.123574  0.181818  0.050000  105.200000
# 2  123.906706  0.463415  0.032216  0.040816  0.280488   93.120000
# 3  115.913556  0.529070  0.147696  0.232558  0.279070  101.984937
# 4  106.136627  0.472222  0.162090  0.274510  0.300000  104.880000

# %% [markdown]
# We now have all games by the home team with calculated stats and all games by away team with calculated stats
# now we have to:
# - concatenate them so we have all games by all teams so we can compute rolling averages (group by (sort?) by team name and date or game id so we can go shift().rolling and get means for the stats)
# - once we do that, we join again so we have joined dataframe of all games with rolling averages for both teams in game

# %%
# must rename both columns stats so we can concatenate
games_by_home_w_stats.columns
# Out:
# Index(['SEASON_ID', 'TEAM_ID', 'TEAM_ABBREVIATION', 'TEAM_NAME', 'GAME_ID',
#        'GAME_DATE', 'MATCHUP', 'WL', 'MIN', 'PTS', 'FGM', 'FGA', 'FG_PCT',
#        'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB', 'DREB',
#        'REB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PLUS_MINUS',
#        'TEAM_ABBREVIATION_A', 'poss_A', 'ortg_A', 'drtg_A', 'eFG_A', 'tovr_A',
#        'orb%_A', 'ftr_A', 'pace_A'],
#       dtype='object')

# %%
games_by_home_w_stats = games_by_home_w_stats.drop(columns=["TEAM_ABBREVIATION_A"])

# %%
a_to_rename = [f'{s}_A' for s in stats]
games_by_home_w_stats = games_by_home_w_stats.rename(columns=dict(zip(a_to_rename, stats)))
games_by_home_w_stats.head()
# Out:
#    SEASON_ID       TEAM_ID TEAM_ABBREVIATION              TEAM_NAME   GAME_ID  \
# 0      22019  1.610613e+09               LAL     Los Angeles Lakers  21900443
# 1      22019  1.610613e+09               MIL        Milwaukee Bucks  21900441
# 2      22019  1.610613e+09               BOS         Boston Celtics  21900440
# 3      22019  1.610613e+09               OKC  Oklahoma City Thunder  21900442
# 4      22019  1.610613e+09               TOR        Toronto Raptors  21900439
#
#    GAME_DATE      MATCHUP WL  MIN  PTS  FGM  FGA  FG_PCT  FG3M  FG3A  FG3_PCT  \
# 0 2019-12-22  LAL vs. DEN  L  240  104   39   83   0.470    10    29    0.345
# 1 2019-12-22  MIL vs. IND  W  242  117   44  104   0.423    15    44    0.341
# 2 2019-12-22  BOS vs. CHA  W  239  119   46   88   0.523    14    32    0.438
# 3 2019-12-22  OKC vs. LAC  W  241  118   46   97   0.474     9    27    0.333
# 4 2019-12-22  TOR vs. DAL  W  242  110   37   94   0.394    10    34    0.294
#
#    FTM  FTA  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  PF  PLUS_MINUS  \
# 0   16   22   0.727    18    27   45   18    7    9   19  25       -24.0
# 1   14   17   0.824    16    45   61   31   10    9    9   7        28.0
# 2   13   16   0.813    10    47   57   25    2    9   11  24        26.0
# 3   17   20   0.850    16    33   49   24   10    4   12  20         6.0
# 4   26   31   0.839    14    37   51   21   12    5   10  21         3.0
#
#      poss        ortg        drtg       eFG      tovr      orb%       ftr  \
# 0   93.68  111.016225  133.056133  0.530120  0.202818  0.400000  0.265060
# 1  104.48  111.983155   84.600760  0.495192  0.086141  0.296296  0.163462
# 2   96.04  123.906706   99.871134  0.602273  0.114536  0.285714  0.181818
# 3  101.80  115.913556  110.279638  0.520619  0.117878  0.333333  0.206186
# 4  103.64  106.136627  102.021358  0.446809  0.096488  0.264151  0.329787
#
#          pace
# 0   93.680000
# 1  103.616529
# 2   96.441841
# 3  101.377593
# 4  102.783471

# %%
games_by_away_w_stats = games_by_away_w_stats.drop(columns=["TEAM_ABBREVIATION_B"])

# %%
games_by_away_w_stats = games_by_away_w_stats.rename(columns=dict(zip([f'{s}_B' for s in stats], stats)))

# %%
all_games_w_stats = pd.concat([games_by_home_w_stats, games_by_away_w_stats])

# %%
all_games_w_stats[all_games_w_stats["GAME_ID"] == 21900443]
# Out:
#    SEASON_ID       TEAM_ID TEAM_ABBREVIATION           TEAM_NAME   GAME_ID  \
# 0      22019  1.610613e+09               LAL  Los Angeles Lakers  21900443
# 0      22019  1.610613e+09               DEN      Denver Nuggets  21900443
#
#    GAME_DATE      MATCHUP WL  MIN  PTS  FGM  FGA  FG_PCT  FG3M  FG3A  FG3_PCT  \
# 0 2019-12-22  LAL vs. DEN  L  240  104   39   83   0.470    10    29    0.345
# 0 2019-12-22    DEN @ LAL  W  241  128   45   92   0.489    11    32    0.344
#
#    FTM  FTA  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  PF  PLUS_MINUS  \
# 0   16   22   0.727    18    27   45   18    7    9   19  25       -24.0
# 0   27   30   0.900    17    27   44   31   13    2    8  19        24.0
#
#     poss        ortg        drtg       eFG      tovr      orb%       ftr  \
# 0  93.68  111.016225  133.056133  0.530120  0.202818  0.400000  0.265060
# 0  96.20  133.056133  111.016225  0.548913  0.083160  0.386364  0.326087
#
#        pace
# 0  93.68000
# 0  95.80083

# %%
all_games_w_stats[all_games_w_stats["TEAM_ABBREVIATION"] == "NYK"]

# %%
all_games_w_stats[all_games_w_stats["TEAM_ABBREVIATION"] == "NYK"].sort_values(["GAME_DATE"]).head(20)
# Out:
#      SEASON_ID       TEAM_ID TEAM_ABBREVIATION        TEAM_NAME   GAME_ID  \
# 15       22019  1.610613e+09               NYK  New York Knicks  21900447
# 25       22019  1.610613e+09               NYK  New York Knicks  21900461
# 37       22019  1.610613e+09               NYK  New York Knicks  21900476
# 65       22019  1.610613e+09               NYK  New York Knicks  21900505
# 79       22019  1.610613e+09               NYK  New York Knicks  21900521
# 99       22019  1.610613e+09               NYK  New York Knicks  21900534
# 111      22019  1.610613e+09               NYK  New York Knicks  21900553
# 123      22019  1.610613e+09               NYK  New York Knicks  21900561
# 130      22019  1.610613e+09               NYK  New York Knicks  21900569
# 151      22019  1.610613e+09               NYK  New York Knicks  21900584
# 159      22019  1.610613e+09               NYK  New York Knicks  21900601
# 179      22019  1.610613e+09               NYK  New York Knicks  21900614
# 197      22019  1.610613e+09               NYK  New York Knicks  21900630
# 201      22019  1.610613e+09               NYK  New York Knicks  21900643
# 222      22019  1.610613e+09               NYK  New York Knicks  21900659
# 234      22019  1.610613e+09               NYK  New York Knicks  21900672
# 252      22019  1.610613e+09               NYK  New York Knicks  21900688
# 263      22019  1.610613e+09               NYK  New York Knicks  21900699
# 273      22019  1.610613e+09               NYK  New York Knicks  21900710
# 291      22019  1.610613e+09               NYK  New York Knicks  21900728
#
#      GAME_DATE      MATCHUP WL  MIN  PTS  FGM  FGA  FG_PCT  FG3M  FG3A  \
# 15  2019-12-23  NYK vs. WAS  L  241  115   44   93   0.473    15    36
# 25  2019-12-26    NYK @ BKN  W  239   94   37   92   0.402     9    29
# 37  2019-12-28    NYK @ WAS  W  240  107   38   85   0.447    11    31
# 65  2020-01-01  NYK vs. POR  W  239  117   47   98   0.480    14    36
# 79  2020-01-03    NYK @ PHX  L  241  112   41   92   0.446    10    37
# 99  2020-01-05    NYK @ LAC  L  241  132   48   84   0.571    12    23
# 111 2020-01-07    NYK @ LAL  L  241   87   37   95   0.389     4    20
# 123 2020-01-08    NYK @ UTA  L  240  104   42   97   0.433     9    25
# 130 2020-01-10  NYK vs. NOP  L  241  111   46  100   0.460     5    27
# 151 2020-01-12  NYK vs. MIA  W  240  124   46   90   0.511     9    31
# 159 2020-01-14    NYK @ MIL  L  239  102   36  102   0.353    11    37
# 179 2020-01-16  NYK vs. PHX  L  240   98   37   90   0.411     8    26
# 197 2020-01-18  NYK vs. PHI  L  241   87   35   88   0.398     6    25
# 201 2020-01-20    NYK @ CLE  W  240  106   41   85   0.482     9    23
# 222 2020-01-22  NYK vs. LAL  L  240   92   36   88   0.409    11    34
# 234 2020-01-24  NYK vs. TOR  L  240  112   42   85   0.494    13    36
# 252 2020-01-26  NYK vs. BKN  W  239  110   49   92   0.533     6    19
# 263 2020-01-28    NYK @ CHA  L  241   92   38   86   0.442     9    32
# 273 2020-01-29  NYK vs. MEM  L  240  106   39   91   0.429     9    28
# 291 2020-02-01    NYK @ IND  W  241   92   34   82   0.415     7    26
#
#      FG3_PCT  FTM  FTA  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  PF  \
# 15     0.417   12   15   0.800    11    33   44   29    4   10   14  25
# 25     0.310   11   15   0.733    13    47   60   16    6    2   13  27
# 37     0.355   20   26   0.769    11    45   56   25    5    5   21  25
# 65     0.389    9   14   0.643     9    46   55   29    3    6    7  14
# 79     0.270   20   30   0.667    13    39   52   19    7    7   15  26
# 99     0.522   24   37   0.649     8    29   37   22   11    4   16  26
# 111    0.200    9   16   0.563    15    32   47   15   10    3   16  20
# 123    0.360   11   11   1.000    14    27   41   18    3    1    9  17
# 130    0.185   14   20   0.700    14    32   46   26   13    1   13  16
# 151    0.290   23   28   0.821    10    29   39   24   11    3    6  23
# 159    0.297   19   26   0.731    12    37   49   26    7    3   11  21
# 179    0.308   16   24   0.667    10    30   40   21   12    3   18  21
# 197    0.240   11   18   0.611    12    36   48   20    4    5   14  18
# 201    0.391   15   17   0.882     7    42   49   17    6    9   10  17
# 222    0.324    9   13   0.692    13    34   47   24    4    4   17  23
# 234    0.361   15   21   0.714    14    32   46   26    5    4   14  21
# 252    0.316    6   13   0.462    14    34   48   19    7    8   13  23
# 263    0.281    7   11   0.636     8    34   42   17    5    7   13  26
# 273    0.321   19   29   0.655    11    35   46   26    9    6   16  22
# 291    0.269   17   23   0.739    14    43   57   19    5    1   12  20
#
#      PLUS_MINUS    poss        ortg        drtg       eFG      tovr      orb%  \
# 15         -6.0  102.60  112.085770  115.019011  0.553763  0.136452  0.255814
# 25         12.0   98.60   95.334686   83.810303  0.451087  0.131846  0.240741
# 37          7.0  106.44  100.526118   93.773443  0.511765  0.197294  0.239130
# 65         24.0  102.16  114.526233   94.320487  0.551020  0.068520  0.195652
# 79         -8.0  107.20  104.477612  113.722517  0.500000  0.139925  0.250000
# 99         -3.0  108.28  121.906169  126.736763  0.642857  0.147765  0.200000
# 111       -30.0  103.04   84.433230  114.436620  0.410526  0.155280  0.263158
# 123       -24.0   96.84  107.393639  134.566863  0.479381  0.092937  0.269231
# 130       -12.0  107.80  102.968460  115.514651  0.485000  0.120594  0.274510
# 151         3.0   98.32  126.118796  125.622924  0.561111  0.061025  0.243902
# 159       -26.0  112.44   90.715048  116.026106  0.406863  0.097830  0.190476
# 179       -23.0  108.56   90.272660  115.325963  0.455556  0.165807  0.204082
# 197        -3.0   97.92   88.848039   95.379398  0.431818  0.142974  0.250000
# 201        20.0   95.48  111.018014   90.071219  0.535294  0.104734  0.159091
# 222        -8.0   97.72   94.146541  107.158165  0.471591  0.173966  0.288889
# 234        -6.0   94.24  118.845501  126.718213  0.570588  0.148557  0.350000
# 252        13.0   96.72  113.730356   98.858541  0.565217  0.134409  0.341463
# 263        -5.0   95.84   95.993322  100.123865  0.494186  0.135643  0.186047
# 273       -21.0  108.76   97.462302  121.507845  0.478022  0.147113  0.229167
# 291         7.0   90.12  102.086107   92.150911  0.457317  0.133156  0.318182
#
#           ftr        pace
# 15   0.161290  102.174274
# 25   0.163043   99.012552
# 37   0.305882  106.440000
# 65   0.142857  102.587448
# 79   0.326087  106.755187
# 99   0.440476  107.830705
# 111  0.168421  102.612448
# 123  0.113402   96.840000
# 130  0.200000  107.352697
# 151  0.311111   98.320000
# 159  0.254902  112.910460
# 179  0.266667  108.560000
# 197  0.204545   97.513693
# 201  0.200000   95.480000
# 222  0.147727   97.720000
# 234  0.247059   94.240000
# 252  0.141304   97.124686
# 263  0.127907   95.442324
# 273  0.318681  108.760000
# 291  0.280488   89.746058

# %%
all_games_w_stats[all_games_w_stats["TEAM_ABBREVIATION"] == "NYK"].sort_values(["GAME_DATE"]).poss.shift(1).rolling(5).mean().head(20)
# Out:
# 15         NaN
# 25         NaN
# 37         NaN
# 65         NaN
# 79         NaN
# 99     103.400
# 111    104.536
# 123    105.424
# 130    103.504
# 151    104.632
# 159    102.856
# 179    103.688
# 197    104.792
# 201    105.008
# 222    102.544
# 234    102.424
# 252     98.784
# 263     96.416
# 273     96.000
# 291     98.656
# Name: poss, dtype: float64

# %%
games_by_home_w_stats.head()
# Out:
#    SEASON_ID       TEAM_ID TEAM_ABBREVIATION              TEAM_NAME   GAME_ID  \
# 0      22019  1.610613e+09               LAL     Los Angeles Lakers  21900443
# 1      22019  1.610613e+09               MIL        Milwaukee Bucks  21900441
# 2      22019  1.610613e+09               BOS         Boston Celtics  21900440
# 3      22019  1.610613e+09               OKC  Oklahoma City Thunder  21900442
# 4      22019  1.610613e+09               TOR        Toronto Raptors  21900439
#
#    GAME_DATE      MATCHUP WL  MIN  PTS  FGM  FGA  FG_PCT  FG3M  FG3A  FG3_PCT  \
# 0 2019-12-22  LAL vs. DEN  L  240  104   39   83   0.470    10    29    0.345
# 1 2019-12-22  MIL vs. IND  W  242  117   44  104   0.423    15    44    0.341
# 2 2019-12-22  BOS vs. CHA  W  239  119   46   88   0.523    14    32    0.438
# 3 2019-12-22  OKC vs. LAC  W  241  118   46   97   0.474     9    27    0.333
# 4 2019-12-22  TOR vs. DAL  W  242  110   37   94   0.394    10    34    0.294
#
#    FTM  FTA  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  PF  PLUS_MINUS  \
# 0   16   22   0.727    18    27   45   18    7    9   19  25       -24.0
# 1   14   17   0.824    16    45   61   31   10    9    9   7        28.0
# 2   13   16   0.813    10    47   57   25    2    9   11  24        26.0
# 3   17   20   0.850    16    33   49   24   10    4   12  20         6.0
# 4   26   31   0.839    14    37   51   21   12    5   10  21         3.0
#
#      poss        ortg        drtg       eFG      tovr      orb%       ftr  \
# 0   93.68  111.016225  133.056133  0.530120  0.202818  0.400000  0.265060
# 1  104.48  111.983155   84.600760  0.495192  0.086141  0.296296  0.163462
# 2   96.04  123.906706   99.871134  0.602273  0.114536  0.285714  0.181818
# 3  101.80  115.913556  110.279638  0.520619  0.117878  0.333333  0.206186
# 4  103.64  106.136627  102.021358  0.446809  0.096488  0.264151  0.329787
#
#          pace
# 0   93.680000
# 1  103.616529
# 2   96.441841
# 3  101.377593
# 4  102.783471

# %%
all_games_w_stats['TEAM_ID'] = all_games_w_stats['TEAM_ID'].astype('int64')
all_games_w_stats.groupby(['TEAM_ID','SEASON_ID'], sort=False).head()

# %%
all_games_copy = all_games_w_stats.sort_values(['TEAM_ID','SEASON_ID','GAME_DATE']).copy()
all_games_copy['TEAM_ID'] = all_games_copy['TEAM_ID'].astype('int64')
for s in stats:
    all_games_copy[f'{s}_S2D'] = (all_games_copy.groupby(['TEAM_ID','SEASON_ID'], sort=False)[s].transform(lambda x: x.shift(1).expanding().mean()))
# Out:
#     SEASON_ID     TEAM_ID TEAM_ABBREVIATION      TEAM_NAME   GAME_ID  \
# 9       22019  1610612737               ATL  Atlanta Hawks  21900444
# 27      22019  1610612737               ATL  Atlanta Hawks  21900469
# 35      22019  1610612737               ATL  Atlanta Hawks  21900477
# 55      22019  1610612737               ATL  Atlanta Hawks  21900491
# 83      22019  1610612737               ATL  Atlanta Hawks  21900517
#
#     GAME_DATE      MATCHUP WL  MIN  PTS  FGM  FGA  FG_PCT  FG3M  FG3A  \
# 9  2019-12-23    ATL @ CLE  L  239  118   45   95   0.474    15    42
# 27 2019-12-27  ATL vs. MIL  L  239   86   33   91   0.363    12    41
# 35 2019-12-28    ATL @ CHI  L  239   81   32   86   0.372     9    34
# 55 2019-12-30    ATL @ ORL  W  240  101   39   81   0.481     9    29
# 83 2020-01-03    ATL @ BOS  L  239  106   39   93   0.419    16    45
#
#     FG3_PCT  FTM  FTA  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  PF  \
# 9     0.357   13   17   0.765     5    32   37   23   11    7   16  20
# 27    0.293    8   14   0.571     8    38   46   20   10    8   18  18
# 35    0.265    8   11   0.727     9    30   39   24    8    5   19  16
# 55    0.310   14   17   0.824    11    41   52   21    8    4   20  20
# 83    0.356   12   15   0.800     6    36   42   26    6    5   14  24
#
#     PLUS_MINUS    poss        ortg        drtg       eFG      tovr      orb%  \
# 9         -3.0  113.48  103.983081  103.171896  0.552632  0.140994  0.121951
# 27       -26.0  107.16   80.253826  103.016924  0.428571  0.167973  0.137931
# 35       -35.0  100.84   80.325268  116.747182  0.424419  0.188417  0.191489
# 55         8.0   97.48  103.610997   95.325953  0.537037  0.205170  0.275000
# 83        -3.0  107.60   98.513011  103.063540  0.505376  0.130112  0.125000
#
#          ftr        pace  poss_S2D    ortg_S2D    drtg_S2D   eFG_S2D  \
# 9   0.178947  113.954812       NaN         NaN         NaN       NaN
# 27  0.153846  107.608368    113.48  103.983081  103.171896  0.552632
# 35  0.127907  101.261925    110.32   92.118453  103.094410  0.490602
# 55  0.209877   97.480000    107.16   88.187392  107.645334  0.468541
# 83  0.161290  108.050209    104.74   92.043293  104.565489  0.485665
#
#     tovr_S2D  orb%_S2D   ftr_S2D    pace_S2D
# 9        NaN       NaN       NaN         NaN
# 27  0.140994  0.121951  0.178947  113.954812
# 35  0.154484  0.129941  0.166397  110.781590
# 55  0.165795  0.150457  0.153567  107.608368
# 83  0.175639  0.181593  0.167644  105.076276

# %%
all_games_copy["game_day_delta"] = (all_games_copy.groupby(['TEAM_ID','SEASON_ID'], sort=False)["GAME_DATE"].transform(lambda x: x.shift(1).expanding().mean()))

# %%
all_games_copy[all_games_copy["TEAM_ABBREVIATION"] == "NYK"]

# %%
all_games_copy.sample(20)

# %%
all_games_copy[all_games_copy["GAME_ID"] == 21900443]
# Out:
#    SEASON_ID     TEAM_ID TEAM_ABBREVIATION           TEAM_NAME   GAME_ID  \
# 0      22019  1610612743               DEN      Denver Nuggets  21900443
# 0      22019  1610612747               LAL  Los Angeles Lakers  21900443
#
#    GAME_DATE      MATCHUP WL  MIN  PTS  FGM  FGA  FG_PCT  FG3M  FG3A  FG3_PCT  \
# 0 2019-12-22    DEN @ LAL  W  241  128   45   92   0.489    11    32    0.344
# 0 2019-12-22  LAL vs. DEN  L  240  104   39   83   0.470    10    29    0.345
#
#    FTM  FTA  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  PF  PLUS_MINUS  \
# 0   27   30   0.900    17    27   44   31   13    2    8  19        24.0
# 0   16   22   0.727    18    27   45   18    7    9   19  25       -24.0
#
#     poss        ortg        drtg       eFG      tovr      orb%       ftr  \
# 0  96.20  133.056133  111.016225  0.548913  0.083160  0.386364  0.326087
# 0  93.68  111.016225  133.056133  0.530120  0.202818  0.400000  0.265060
#
#        pace  poss_S2D  ortg_S2D  drtg_S2D  eFG_S2D  tovr_S2D  orb%_S2D  \
# 0  95.80083       NaN       NaN       NaN      NaN       NaN       NaN
# 0  93.68000       NaN       NaN       NaN      NaN       NaN       NaN
#
#    ftr_S2D  pace_S2D
# 0      NaN       NaN
# 0      NaN       NaN

# %%
games_by_home_w_stats[games_by_home_w_stats["GAME_ID"] == 21900443]
# Out:
#    SEASON_ID       TEAM_ID TEAM_ABBREVIATION           TEAM_NAME   GAME_ID  \
# 0      22019  1.610613e+09               LAL  Los Angeles Lakers  21900443
#
#    GAME_DATE      MATCHUP WL  MIN  PTS  FGM  FGA  FG_PCT  FG3M  FG3A  FG3_PCT  \
# 0 2019-12-22  LAL vs. DEN  L  240  104   39   83    0.47    10    29    0.345
#
#    FTM  FTA  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  PF  PLUS_MINUS  \
# 0   16   22   0.727    18    27   45   18    7    9   19  25       -24.0
#
#     poss        ortg        drtg      eFG      tovr  orb%      ftr   pace
# 0  93.68  111.016225  133.056133  0.53012  0.202818   0.4  0.26506  93.68

# %%
reduced_all_games_copy = all_games_copy[["GAME_ID", "TEAM_ABBREVIATION", "MATCHUP"] + [f'{s}_S2D' for s in stats]]

# %%
games_joined_w_s2d_stats = games_by_home_w_stats.merge(all_games_copy[["GAME_ID", "TEAM_ABBREVIATION", "MATCHUP"] + [f'{s}_S2D' for s in stats]], how="inner", on=["GAME_ID", "TEAM_ABBREVIATION", "MATCHUP"])

# %%
games_joined_w_s2d_stats.sample(5)
# Out:
#       SEASON_ID       TEAM_ID TEAM_ABBREVIATION          TEAM_NAME   GAME_ID  \
# 2365      22021  1.610613e+09               CHA  Charlotte Hornets  22100501
# 300       22019  1.610613e+09               DET    Detroit Pistons  21900737
# 234       22019  1.610613e+09               NYK    New York Knicks  21900672
# 4072      22022  1.610613e+09               TOR    Toronto Raptors  22200890
# 3360      22022  1.610613e+09               MIA         Miami Heat  22200174
#
#       GAME_DATE      MATCHUP WL  MIN  PTS  FGM  FGA  FG_PCT  FG3M  FG3A  \
# 2365 2021-12-27  CHA vs. HOU  W  240  123   47   88   0.534    18    41
# 300  2020-02-02  DET vs. DEN  W  264  128   48   94   0.511    14    31
# 234  2020-01-24  NYK vs. TOR  L  240  112   42   85   0.494    13    36
# 4072 2023-02-23  TOR vs. NOP  W  240  115   43   92   0.467     9    31
# 3360 2022-11-10  MIA vs. CHA  W  266  117   39   90   0.433    10    36
#
#       FG3_PCT  FTM  FTA  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  PF  \
# 2365    0.439   11   14   0.786     7    32   39   33   13    4   16  18
# 300     0.452   18   24   0.750    11    32   43   33    4    2   11  22
# 234     0.361   15   21   0.714    14    32   46   26    5    4   14  21
# 4072    0.290   20   25   0.800    11    37   48   17   10    5   11  20
# 3360    0.278   29   36   0.806     8    30   38   21    9    1   10  25
#
#       PLUS_MINUS    poss        ortg        drtg       eFG      tovr  \
# 2365        24.0  103.16  119.232261   96.191216  0.636364  0.155099
# 300          5.0  104.56  122.417751  122.169249  0.585106  0.105203
# 234         -6.0   94.24  118.845501  126.718213  0.570588  0.148557
# 4072         5.0  103.00  111.650485  107.843137  0.516304  0.106796
# 3360         5.0  107.84  108.494065  102.941176  0.488889  0.092730
#
#           orb%       ftr        pace    poss_S2D    ortg_S2D    drtg_S2D  \
# 2365  0.184211  0.159091  103.160000  103.564706  111.136101  112.814772
# 300   0.250000  0.255319   95.054545  101.854000  107.930520  112.002824
# 234   0.350000  0.247059   94.240000  102.893333  102.984734  109.432295
# 4072  0.229167  0.271739  103.000000  100.529492  112.951347  112.905182
# 3360  0.160000  0.400000   97.299248   99.447273  108.715823  109.580159
#
#        eFG_S2D  tovr_S2D  orb%_S2D   ftr_S2D    pace_S2D
# 2365  0.537597  0.119655  0.223800  0.224928  102.350254
# 300   0.529648  0.138149  0.217156  0.299156  100.324053
# 234   0.496509  0.129130  0.234978  0.227094  102.807298
# 4072  0.517958  0.113129  0.275274  0.278058   99.800231
# 3360  0.520244  0.133086  0.205998  0.262110   99.368048

# %%
away_games_w_s2d = reduced_all_games_copy[(reduced_all_games_copy["MATCHUP"].str.contains("@"))]

# %%
away_games_w_s2d.head()
# Out:
#       GAME_ID TEAM_ABBREVIATION    MATCHUP  poss_S2D    ortg_S2D    drtg_S2D  \
# 9    21900444               ATL  ATL @ CLE       NaN         NaN         NaN
# 35   21900477               ATL  ATL @ CHI    110.32   92.118453  103.094410
# 55   21900491               ATL  ATL @ ORL    107.16   88.187392  107.645334
# 83   21900517               ATL  ATL @ BOS    104.74   92.043293  104.565489
# 135  21900567               ATL  ATL @ WAS    104.76  100.155185  108.473299
#
#       eFG_S2D  tovr_S2D  orb%_S2D   ftr_S2D    pace_S2D
# 9         NaN       NaN       NaN       NaN         NaN
# 35   0.490602  0.154484  0.129941  0.166397  110.781590
# 55   0.468541  0.165795  0.150457  0.153567  107.608368
# 83   0.485665  0.175639  0.181593  0.167644  105.076276
# 135  0.502735  0.145141  0.170144  0.224356  104.976641

# %%
games_joined_w_s2d_stats = games_joined_w_s2d_stats.merge(reduced_all_games_copy[(reduced_all_games_copy["MATCHUP"].str.contains("@"))], on="GAME_ID", suffixes=("_A", "_B"))

# %%
games_joined_w_s2d_stats[games_joined_w_s2d_stats["GAME_ID"] == 21900672]
# Out:
#      SEASON_ID       TEAM_ID TEAM_ABBREVIATION_A        TEAM_NAME   GAME_ID  \
# 234      22019  1.610613e+09                 NYK  New York Knicks  21900672
#
#      GAME_DATE    MATCHUP_A WL  MIN  PTS  FGM  FGA  FG_PCT  FG3M  FG3A  \
# 234 2020-01-24  NYK vs. TOR  L  240  112   42   85   0.494    13    36
#
#      FG3_PCT  FTM  FTA  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  PF  \
# 234    0.361   15   21   0.714    14    32   46   26    5    4   14  21
#
#      PLUS_MINUS   poss        ortg        drtg       eFG      tovr  orb%  \
# 234        -6.0  94.24  118.845501  126.718213  0.570588  0.148557  0.35
#
#           ftr   pace  poss_S2D_A  ortg_S2D_A  drtg_S2D_A  eFG_S2D_A  \
# 234  0.247059  94.24  102.893333  102.984734  109.432295   0.496509
#
#      tovr_S2D_A  orb%_S2D_A  ftr_S2D_A  pace_S2D_A TEAM_ABBREVIATION_B  \
# 234     0.12913    0.234978   0.227094  102.807298                 TOR
#
#      MATCHUP_B  poss_S2D_B  ortg_S2D_B  drtg_S2D_B  eFG_S2D_B  tovr_S2D_B  \
# 234  TOR @ NYK      101.92  109.363489  103.247451   0.532291    0.133501
#
#      orb%_S2D_B  ftr_S2D_B  pace_S2D_B
# 234    0.233237   0.235019  100.548082

# %%
all_games_copy[all_games_copy["GAME_ID"] == 21900672]
# Out:
#      SEASON_ID     TEAM_ID TEAM_ABBREVIATION        TEAM_NAME   GAME_ID  \
# 234      22019  1610612752               NYK  New York Knicks  21900672
# 233      22019  1610612761               TOR  Toronto Raptors  21900672
#
#      GAME_DATE      MATCHUP WL  MIN  PTS  FGM  FGA  FG_PCT  FG3M  FG3A  \
# 234 2020-01-24  NYK vs. TOR  L  240  112   42   85   0.494    13    36
# 233 2020-01-24    TOR @ NYK  W  240  118   41   81   0.506    17    35
#
#      FG3_PCT  FTM  FTA  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  PF  \
# 234    0.361   15   21   0.714    14    32   46   26    5    4   14  21
# 233    0.486   19   23   0.826     5    26   31   25   10    6    7  20
#
#      PLUS_MINUS   poss        ortg        drtg       eFG      tovr      orb%  \
# 234        -6.0  94.24  118.845501  126.718213  0.570588  0.148557  0.350000
# 233         6.0  93.12  126.718213  118.845501  0.611111  0.075172  0.135135
#
#           ftr   pace    poss_S2D    ortg_S2D    drtg_S2D   eFG_S2D  tovr_S2D  \
# 234  0.247059  94.24  102.893333  102.984734  109.432295  0.496509  0.129130
# 233  0.283951  93.12  101.920000  109.363489  103.247451  0.532291  0.133501
#
#      orb%_S2D   ftr_S2D    pace_S2D
# 234  0.234978  0.227094  102.807298
# 233  0.233237  0.235019  100.548082

# %%
feature_set = games_joined_w_s2d_stats[["SEASON_ID", "GAME_DATE", "GAME_ID", "TEAM_NAME", "TEAM_ABBREVIATION_A", "TEAM_ABBREVIATION_B", "MATCHUP_A", "MATCHUP_B", "WL"] + [f'{s}_S2D_A' for s in stats] + [f'{s}_S2D_B' for s in stats]]

# %%
feature_set = feature_set.dropna()

# %%
feature_set.head()
# Out:
#     SEASON_ID  GAME_DATE   GAME_ID              TEAM_NAME TEAM_ABBREVIATION_A  \
# 8       22019 2019-12-23  21900446         Indiana Pacers                 IND
# 16      22019 2019-12-25  21900458     Los Angeles Lakers                 LAL
# 17      22019 2019-12-25  21900457  Golden State Warriors                 GSW
# 18      22019 2019-12-25  21900456     Philadelphia 76ers                 PHI
# 19      22019 2019-12-25  21900459         Denver Nuggets                 DEN
#
#    TEAM_ABBREVIATION_B    MATCHUP_A  MATCHUP_B WL  poss_S2D_A  ortg_S2D_A  \
# 8                  TOR  IND vs. TOR  TOR @ IND  W      105.20   84.600760
# 16                 LAC  LAL vs. LAC  LAC @ LAL  L       93.68  111.016225
# 17                 HOU  GSW vs. HOU  HOU @ GSW  W      106.20  106.403013
# 18                 MIL  PHI vs. MIL  MIL @ PHI  W       94.84  131.800928
# 19                 NOP  DEN vs. NOP  NOP @ DEN  L       97.90  123.254974
#
#     drtg_S2D_A  eFG_S2D_A  tovr_S2D_A  orb%_S2D_A  ftr_S2D_A  pace_S2D_A  \
# 8   111.983155   0.430000    0.123574    0.181818   0.050000  105.200000
# 16  133.056133   0.530120    0.202818    0.400000   0.265060   93.680000
# 17   97.414762   0.505747    0.178908    0.295455   0.344828  106.644351
# 18  110.190053   0.610526    0.126529    0.414634   0.115789   94.840000
# 19  109.433492   0.598174    0.147002    0.278896   0.259197   97.908783
#
#     poss_S2D_B  ortg_S2D_B  drtg_S2D_B  eFG_S2D_B  tovr_S2D_B  orb%_S2D_B  \
# 8       103.64  106.136627  102.021358   0.446809    0.096488    0.264151
# 16      101.56  110.279638  115.913556   0.529070    0.147696    0.232558
# 17      102.12  110.654132  100.853375   0.534483    0.107716    0.136364
# 18      104.48  111.983155   84.600760   0.495192    0.086141    0.296296
# 19       99.04  102.988691   92.229199   0.489247    0.121163    0.245283
#
#     ftr_S2D_B  pace_S2D_B
# 8    0.329787  102.783471
# 16   0.279070  101.984937
# 17   0.264368  101.696266
# 18   0.163462  103.616529
# 19   0.172043   99.454393

# %%
feature_set[[f'{s}_S2D_A' for s in stats] + [f'{s}_S2D_B' for s in stats]].to_numpy()
# Out:
# array([[105.2       ,  84.60076046, 111.98315467, ...,   0.26415094,
#           0.32978723, 102.78347107],
#        [ 93.68      , 111.01622545, 133.05613306, ...,   0.23255814,
#           0.27906977, 101.98493724],
#        [106.2       , 106.40301318,  97.41476208, ...,   0.13636364,
#           0.26436782, 101.69626556],
#        ...,
#        [101.77      , 114.21357583, 104.56379824, ...,   0.18557022,
#           0.28748131, 100.09038357],
#        [100.98666667, 114.44211302, 111.9533269 , ...,   0.26001184,
#           0.28951213, 101.29625684],
#        [101.72363636, 113.31854912, 104.86533409, ...,   0.19771191,
#           0.29032814, 100.11800241]], shape=(6978, 16))

# %%
training_set = feature_set[feature_set["GAME_DATE"] < "2023"]

# %%
training_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3644 entries, 8 to 3731
# Data columns (total 25 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   SEASON_ID            3644 non-null   int64
#  1   GAME_DATE            3644 non-null   datetime64[ns]
#  2   GAME_ID              3644 non-null   int64
#  3   TEAM_NAME            3644 non-null   object
#  4   TEAM_ABBREVIATION_A  3644 non-null   object
#  5   TEAM_ABBREVIATION_B  3644 non-null   object
#  6   MATCHUP_A            3644 non-null   object
#  7   MATCHUP_B            3644 non-null   object
#  8   WL                   3644 non-null   object
#  9   poss_S2D_A           3644 non-null   float64
#  10  ortg_S2D_A           3644 non-null   float64
#  11  drtg_S2D_A           3644 non-null   float64
#  12  eFG_S2D_A            3644 non-null   float64
#  13  tovr_S2D_A           3644 non-null   float64
#  14  orb%_S2D_A           3644 non-null   float64
#  15  ftr_S2D_A            3644 non-null   float64
#  16  pace_S2D_A           3644 non-null   float64
#  17  poss_S2D_B           3644 non-null   float64
#  18  ortg_S2D_B           3644 non-null   float64
#  19  drtg_S2D_B           3644 non-null   float64
#  20  eFG_S2D_B            3644 non-null   float64
#  21  tovr_S2D_B           3644 non-null   float64
#  22  orb%_S2D_B           3644 non-null   float64
#  23  ftr_S2D_B            3644 non-null   float64
#  24  pace_S2D_B           3644 non-null   float64
# dtypes: datetime64[ns](1), float64(16), int64(2), object(6)
# memory usage: 740.2+ KB

# %%
training_set.head()
# Out:
#     SEASON_ID  GAME_DATE   GAME_ID              TEAM_NAME TEAM_ABBREVIATION_A  \
# 8       22019 2019-12-23  21900446         Indiana Pacers                 IND
# 16      22019 2019-12-25  21900458     Los Angeles Lakers                 LAL
# 17      22019 2019-12-25  21900457  Golden State Warriors                 GSW
# 18      22019 2019-12-25  21900456     Philadelphia 76ers                 PHI
# 19      22019 2019-12-25  21900459         Denver Nuggets                 DEN
#
#    TEAM_ABBREVIATION_B    MATCHUP_A  MATCHUP_B WL  poss_S2D_A  ortg_S2D_A  \
# 8                  TOR  IND vs. TOR  TOR @ IND  W      105.20   84.600760
# 16                 LAC  LAL vs. LAC  LAC @ LAL  L       93.68  111.016225
# 17                 HOU  GSW vs. HOU  HOU @ GSW  W      106.20  106.403013
# 18                 MIL  PHI vs. MIL  MIL @ PHI  W       94.84  131.800928
# 19                 NOP  DEN vs. NOP  NOP @ DEN  L       97.90  123.254974
#
#     drtg_S2D_A  eFG_S2D_A  tovr_S2D_A  orb%_S2D_A  ftr_S2D_A  pace_S2D_A  \
# 8   111.983155   0.430000    0.123574    0.181818   0.050000  105.200000
# 16  133.056133   0.530120    0.202818    0.400000   0.265060   93.680000
# 17   97.414762   0.505747    0.178908    0.295455   0.344828  106.644351
# 18  110.190053   0.610526    0.126529    0.414634   0.115789   94.840000
# 19  109.433492   0.598174    0.147002    0.278896   0.259197   97.908783
#
#     poss_S2D_B  ortg_S2D_B  drtg_S2D_B  eFG_S2D_B  tovr_S2D_B  orb%_S2D_B  \
# 8       103.64  106.136627  102.021358   0.446809    0.096488    0.264151
# 16      101.56  110.279638  115.913556   0.529070    0.147696    0.232558
# 17      102.12  110.654132  100.853375   0.534483    0.107716    0.136364
# 18      104.48  111.983155   84.600760   0.495192    0.086141    0.296296
# 19       99.04  102.988691   92.229199   0.489247    0.121163    0.245283
#
#     ftr_S2D_B  pace_S2D_B
# 8    0.329787  102.783471
# 16   0.279070  101.984937
# 17   0.264368  101.696266
# 18   0.163462  103.616529
# 19   0.172043   99.454393

# %%
training_set['win_int'] = (training_set['WL'] == 'W').astype(int)
training_set.head()
# Out:
# C:\Users\Jon\AppData\Local\Temp\ipykernel_40464\2597983711.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   training_set['win_int'] = (training_set['WL'] == 'W').astype(int)
#     SEASON_ID  GAME_DATE   GAME_ID              TEAM_NAME TEAM_ABBREVIATION_A  \
# 8       22019 2019-12-23  21900446         Indiana Pacers                 IND
# 16      22019 2019-12-25  21900458     Los Angeles Lakers                 LAL
# 17      22019 2019-12-25  21900457  Golden State Warriors                 GSW
# 18      22019 2019-12-25  21900456     Philadelphia 76ers                 PHI
# 19      22019 2019-12-25  21900459         Denver Nuggets                 DEN
#
#    TEAM_ABBREVIATION_B    MATCHUP_A  MATCHUP_B WL  poss_S2D_A  ortg_S2D_A  \
# 8                  TOR  IND vs. TOR  TOR @ IND  W      105.20   84.600760
# 16                 LAC  LAL vs. LAC  LAC @ LAL  L       93.68  111.016225
# 17                 HOU  GSW vs. HOU  HOU @ GSW  W      106.20  106.403013
# 18                 MIL  PHI vs. MIL  MIL @ PHI  W       94.84  131.800928
# 19                 NOP  DEN vs. NOP  NOP @ DEN  L       97.90  123.254974
#
#     drtg_S2D_A  eFG_S2D_A  tovr_S2D_A  orb%_S2D_A  ftr_S2D_A  pace_S2D_A  \
# 8   111.983155   0.430000    0.123574    0.181818   0.050000  105.200000
# 16  133.056133   0.530120    0.202818    0.400000   0.265060   93.680000
# 17   97.414762   0.505747    0.178908    0.295455   0.344828  106.644351
# 18  110.190053   0.610526    0.126529    0.414634   0.115789   94.840000
# 19  109.433492   0.598174    0.147002    0.278896   0.259197   97.908783
#
#     poss_S2D_B  ortg_S2D_B  drtg_S2D_B  eFG_S2D_B  tovr_S2D_B  orb%_S2D_B  \
# 8       103.64  106.136627  102.021358   0.446809    0.096488    0.264151
# 16      101.56  110.279638  115.913556   0.529070    0.147696    0.232558
# 17      102.12  110.654132  100.853375   0.534483    0.107716    0.136364
# 18      104.48  111.983155   84.600760   0.495192    0.086141    0.296296
# 19       99.04  102.988691   92.229199   0.489247    0.121163    0.245283
#
#     ftr_S2D_B  pace_S2D_B  win_int
# 8    0.329787  102.783471        1
# 16   0.279070  101.984937        0
# 17   0.264368  101.696266        1
# 18   0.163462  103.616529        1
# 19   0.172043   99.454393        0

# %%
final_x_train = training_set[[f'{s}_S2D_A' for s in stats] + [f'{s}_S2D_B' for s in stats]]

# %%
final_y_train = training_set["win_int"]

# %%
final_x_train.head()
# Out:
#     poss_S2D_A  ortg_S2D_A  drtg_S2D_A  eFG_S2D_A  tovr_S2D_A  orb%_S2D_A  \
# 8       105.20   84.600760  111.983155   0.430000    0.123574    0.181818
# 16       93.68  111.016225  133.056133   0.530120    0.202818    0.400000
# 17      106.20  106.403013   97.414762   0.505747    0.178908    0.295455
# 18       94.84  131.800928  110.190053   0.610526    0.126529    0.414634
# 19       97.90  123.254974  109.433492   0.598174    0.147002    0.278896
#
#     ftr_S2D_A  pace_S2D_A  poss_S2D_B  ortg_S2D_B  drtg_S2D_B  eFG_S2D_B  \
# 8    0.050000  105.200000      103.64  106.136627  102.021358   0.446809
# 16   0.265060   93.680000      101.56  110.279638  115.913556   0.529070
# 17   0.344828  106.644351      102.12  110.654132  100.853375   0.534483
# 18   0.115789   94.840000      104.48  111.983155   84.600760   0.495192
# 19   0.259197   97.908783       99.04  102.988691   92.229199   0.489247
#
#     tovr_S2D_B  orb%_S2D_B  ftr_S2D_B  pace_S2D_B
# 8     0.096488    0.264151   0.329787  102.783471
# 16    0.147696    0.232558   0.279070  101.984937
# 17    0.107716    0.136364   0.264368  101.696266
# 18    0.086141    0.296296   0.163462  103.616529
# 19    0.121163    0.245283   0.172043   99.454393

# %%
final_y_train.head()
# Out:
# 8     1
# 16    0
# 17    1
# 18    1
# 19    0
# Name: win_int, dtype: int64

# %%
final_x_train.to_csv("x_train.csv", index=False)
final_y_train.to_csv("y_train.csv", index=False)

# %%
val_set = feature_set[(feature_set["GAME_DATE"] > "2023") & (feature_set["GAME_DATE"] < "2024")]

# %%
val_set['win_int'] = (val_set['WL'] == 'W').astype(int)
val_set.head()
# Out:
# C:\Users\Jon\AppData\Local\Temp\ipykernel_40464\4056833670.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   val_set['win_int'] = (val_set['WL'] == 'W').astype(int)
#       SEASON_ID  GAME_DATE   GAME_ID               TEAM_NAME  \
# 3735      22022 2023-01-02  22200551       Charlotte Hornets
# 3736      22022 2023-01-02  22200552     Cleveland Cavaliers
# 3737      22022 2023-01-02  22200557  Minnesota Timberwolves
# 3738      22022 2023-01-02  22200553          Indiana Pacers
# 3739      22022 2023-01-02  22200556         Houston Rockets
#
#      TEAM_ABBREVIATION_A TEAM_ABBREVIATION_B    MATCHUP_A  MATCHUP_B WL  \
# 3735                 CHA                 LAL  CHA vs. LAL  LAL @ CHA  L
# 3736                 CLE                 CHI  CLE vs. CHI  CHI @ CLE  W
# 3737                 MIN                 DEN  MIN vs. DEN  DEN @ MIN  W
# 3738                 IND                 TOR  IND vs. TOR  TOR @ IND  W
# 3739                 HOU                 DAL  HOU vs. DAL  DAL @ HOU  L
#
#       poss_S2D_A  ortg_S2D_A  drtg_S2D_A  eFG_S2D_A  tovr_S2D_A  orb%_S2D_A  \
# 3735  104.367568  106.650756  113.143758   0.503541    0.129814    0.263795
# 3736   98.761081  112.788529  107.571886   0.552899    0.138709    0.238632
# 3737  103.674595  110.400770  111.294967   0.555235    0.149340    0.213035
# 3738  103.934054  111.163394  113.241497   0.547383    0.138290    0.220091
# 3739  102.291111  106.929396  114.261313   0.510105    0.159880    0.302569
#
#       ftr_S2D_A  pace_S2D_A  poss_S2D_B  ortg_S2D_B  drtg_S2D_B  eFG_S2D_B  \
# 3735   0.251614  102.736492  104.706667  110.949946  112.776430   0.541162
# 3736   0.278573   97.019862  102.125556  111.497903  111.807346   0.546542
# 3737   0.277334  103.349111  100.805556  115.708652  113.478566   0.581218
# 3738   0.260135  103.794620  100.268889  111.076204  112.239870   0.511093
# 3739   0.291661  101.605292   98.967568  113.826442  111.994620   0.563363
#
#       tovr_S2D_B  orb%_S2D_B  ftr_S2D_B  pace_S2D_B  win_int
# 3735    0.135685    0.213276   0.284582  103.745366        0
# 3736    0.132665    0.200449   0.258178  100.923870        1
# 3737    0.144647    0.237261   0.267618  100.161120        1
# 3738    0.119262    0.270276   0.281170   99.680484        1
# 3739    0.120754    0.188180   0.309092   97.604704        0

# %%
x_val = val_set[[f'{s}_S2D_A' for s in stats] + [f'{s}_S2D_B' for s in stats]]
y_val = val_set["win_int"]

# %%
x_val.to_csv("x_val_set.csv", index=False)
y_val.to_csv("y_val_set.csv", index=False)

# %%
feature_set.head()
# Out:
#     SEASON_ID  GAME_DATE   GAME_ID              TEAM_NAME TEAM_ABBREVIATION_A  \
# 8       22019 2019-12-23  21900446         Indiana Pacers                 IND
# 16      22019 2019-12-25  21900458     Los Angeles Lakers                 LAL
# 17      22019 2019-12-25  21900457  Golden State Warriors                 GSW
# 18      22019 2019-12-25  21900456     Philadelphia 76ers                 PHI
# 19      22019 2019-12-25  21900459         Denver Nuggets                 DEN
#
#    TEAM_ABBREVIATION_B    MATCHUP_A  MATCHUP_B WL  poss_S2D_A  ortg_S2D_A  \
# 8                  TOR  IND vs. TOR  TOR @ IND  W      105.20   84.600760
# 16                 LAC  LAL vs. LAC  LAC @ LAL  L       93.68  111.016225
# 17                 HOU  GSW vs. HOU  HOU @ GSW  W      106.20  106.403013
# 18                 MIL  PHI vs. MIL  MIL @ PHI  W       94.84  131.800928
# 19                 NOP  DEN vs. NOP  NOP @ DEN  L       97.90  123.254974
#
#     drtg_S2D_A  eFG_S2D_A  tovr_S2D_A  orb%_S2D_A  ftr_S2D_A  pace_S2D_A  \
# 8   111.983155   0.430000    0.123574    0.181818   0.050000  105.200000
# 16  133.056133   0.530120    0.202818    0.400000   0.265060   93.680000
# 17   97.414762   0.505747    0.178908    0.295455   0.344828  106.644351
# 18  110.190053   0.610526    0.126529    0.414634   0.115789   94.840000
# 19  109.433492   0.598174    0.147002    0.278896   0.259197   97.908783
#
#     poss_S2D_B  ortg_S2D_B  drtg_S2D_B  eFG_S2D_B  tovr_S2D_B  orb%_S2D_B  \
# 8       103.64  106.136627  102.021358   0.446809    0.096488    0.264151
# 16      101.56  110.279638  115.913556   0.529070    0.147696    0.232558
# 17      102.12  110.654132  100.853375   0.534483    0.107716    0.136364
# 18      104.48  111.983155   84.600760   0.495192    0.086141    0.296296
# 19       99.04  102.988691   92.229199   0.489247    0.121163    0.245283
#
#     ftr_S2D_B  pace_S2D_B
# 8    0.329787  102.783471
# 16   0.279070  101.984937
# 17   0.264368  101.696266
# 18   0.163462  103.616529
# 19   0.172043   99.454393

# %%
# Create delta feature set where stats for each team are subtracted from each other
stat_delta_training_set = training_set[[f'{s}_S2D_A' for s in stats]].subtract(training_set[[f'{s}_S2D_B' for s in stats]].rename(columns=dict(zip([f'{s}_S2D_B' for s in stats], [f'{s}_S2D_A' for s in stats]))), fill_value=0)

# %%
stat_delta_val_set = val_set[[f'{s}_S2D_A' for s in stats]].subtract(val_set[[f'{s}_S2D_B' for s in stats]].rename(columns=dict(zip([f'{s}_S2D_B' for s in stats], [f'{s}_S2D_A' for s in stats]))), fill_value=0)

# %%
stat_delta_training_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3644 entries, 8 to 3731
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   poss_S2D_A  3644 non-null   float64
#  1   ortg_S2D_A  3644 non-null   float64
#  2   drtg_S2D_A  3644 non-null   float64
#  3   eFG_S2D_A   3644 non-null   float64
#  4   tovr_S2D_A  3644 non-null   float64
#  5   orb%_S2D_A  3644 non-null   float64
#  6   ftr_S2D_A   3644 non-null   float64
#  7   pace_S2D_A  3644 non-null   float64
# dtypes: float64(8)
# memory usage: 256.2 KB

# %%
final_y_train.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 3644 entries, 8 to 3731
# Series name: win_int
# Non-Null Count  Dtype
# --------------  -----
# 3644 non-null   int64
# dtypes: int64(1)
# memory usage: 56.9 KB

# %%
stat_delta_val_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1222 entries, 3735 to 4979
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   poss_S2D_A  1222 non-null   float64
#  1   ortg_S2D_A  1222 non-null   float64
#  2   drtg_S2D_A  1222 non-null   float64
#  3   eFG_S2D_A   1222 non-null   float64
#  4   tovr_S2D_A  1222 non-null   float64
#  5   orb%_S2D_A  1222 non-null   float64
#  6   ftr_S2D_A   1222 non-null   float64
#  7   pace_S2D_A  1222 non-null   float64
# dtypes: float64(8)
# memory usage: 85.9 KB

# %%
stat_delta_training_set.to_csv("stat_delta_x_train.csv", index=False)
stat_delta_val_set.to_csv("stat_delta_x_val.csv", index=False)
